# %%
from __future__ import print_function
import os
import numpy as np
import random
import string
import tensorflow as tf
import zipfile
from six.moves import range
from six.moves.urllib.request import urlretrieve

# %%
f = open('text8', "r")
text = tf.compat.as_str(f.read())
print('Data size %d' % len(text))
# Out:
# Data size 100000000

# %%
# Create a small validation set.
valid_size = 1000
valid_text = text[:valid_size]
train_text = text[valid_size:]
train_size = len(train_text)
print(train_size, train_text[:64])
print(valid_size, valid_text[:64])
# Out:
# 99999000 ons anarchists advocate social relations based upon voluntary as
# 1000  anarchism originated as a term of abuse first used against earl

# %%
# Utility functions to map characters to vocabulary IDs and back.
vocabulary_size = len(string.ascii_lowercase) + 1 # [a-z] + ' '
first_letter = ord(string.ascii_lowercase[0])

def char2id(char):
    if char in string.ascii_lowercase:
        return ord(char) - first_letter + 1
    elif char == ' ':
        return 0
    else:
        print('Unexpected character: %s' % char)
        return 0

def id2char(dictid):
    if dictid > 0:
        return chr(dictid + first_letter - 1)
    else:
        return ' '

print(char2id('a'), char2id('z'), char2id(' '), char2id('ï'))
print(id2char(1), id2char(26), id2char(0))
# Out:
# Unexpected character: ï
# 1 26 0 0
# a z

# %%
# Function to generate a training batch for the LSTM model.
batch_size=64
num_unrollings=10
class BatchGenerator(object):
    def __init__(self, text, batch_size, num_unrollings):
        self._text = text
        self._text_size = len(text)
        self._batch_size = batch_size
        self._num_unrollings = num_unrollings
        segment = self._text_size // batch_size
        self._cursor = [ offset * segment for offset in range(batch_size)]
        self._last_batch = self._next_batch()
        
    def _next_batch(self):
        """Generate a single batch from the current cursor position in the data."""
        batch = np.zeros(shape=(self._batch_size, vocabulary_size), dtype=np.float)
        for b in range(self._batch_size):
            batch[b, char2id(self._text[self._cursor[b]])] = 1.0
            self._cursor[b] = (self._cursor[b] + 1) % self._text_size
        return batch
    
    def next(self):
        """Generate the next array of batches from the data. The array consists of
        the last batch of the previous array, followed by num_unrollings new ones.
        """
        batches = [self._last_batch]
        for step in range(self._num_unrollings):
            batches.append(self._next_batch())
        self._last_batch = batches[-1]
        return batches
    
def characters(probabilities):
    """Turn a 1-hot encoding or a probability distribution over the possible
    characters back into its (most likely) character representation."""
    return [id2char(c) for c in np.argmax(probabilities, 1)]
    
def batches2string(batches):
    """Convert a sequence of batches back into their (most likely) string
    representation."""
    s = [''] * batches[0].shape[0]
    for b in batches:
        s = [''.join(x) for x in zip(s, characters(b))]
    return s
    
train_batches = BatchGenerator(train_text, batch_size, num_unrollings)
valid_batches = BatchGenerator(valid_text, 1, 1)
    
print(batches2string(train_batches.next()))
print(batches2string(train_batches.next()))
print(batches2string(valid_batches.next()))
print(batches2string(valid_batches.next()))
# Out:
# ['ons anarchi', 'when milita', 'lleria arch', ' abbeys and', 'married urr', 'hel and ric', 'y and litur', 'ay opened f', 'tion from t', 'migration t', 'new york ot', 'he boeing s', 'e listed wi', 'eber has pr', 'o be made t', 'yer who rec', 'ore signifi', 'a fierce cr', ' two six ei', 'aristotle s', 'ity can be ', ' and intrac', 'tion of the', 'dy to pass ', 'f certain d', 'at it will ', 'e convince ', 'ent told hi', 'ampaign and', 'rver side s', 'ious texts ', 'o capitaliz', 'a duplicate', 'gh ann es d', 'ine january', 'ross zero t', 'cal theorie', 'ast instanc', ' dimensiona', 'most holy m', 't s support', 'u is still ', 'e oscillati', 'o eight sub', 'of italy la', 's the tower', 'klahoma pre', 'erprise lin', 'ws becomes ', 'et in a naz', 'the fabian ', 'etchy to re', ' sharman ne', 'ised empero', 'ting in pol', 'd neo latin', 'th risky ri', 'encyclopedi', 'fense the a', 'duating fro', 'treet grid ', 'ations more', 'appeal of d', 'si have mad']
# ['ists advoca', 'ary governm', 'hes nationa', 'd monasteri', 'raca prince', 'chard baer ', 'rgical lang', 'for passeng', 'the nationa', 'took place ', 'ther well k', 'seven six s', 'ith a gloss', 'robably bee', 'to recogniz', 'ceived the ', 'icant than ', 'ritic of th', 'ight in sig', 's uncaused ', ' lost as in', 'cellular ic', 'e size of t', ' him a stic', 'drugs confu', ' take to co', ' the priest', 'im to name ', 'd barred at', 'standard fo', ' such as es', 'ze on the g', 'e of the or', 'd hiver one', 'y eight mar', 'the lead ch', 'es classica', 'ce the non ', 'al analysis', 'mormons bel', 't or at lea', ' disagreed ', 'ing system ', 'btypes base', 'anguages th', 'r commissio', 'ess one nin', 'nux suse li', ' the first ', 'zi concentr', ' society ne', 'elatively s', 'etworks sha', 'or hirohito', 'litical ini', 'n most of t', 'iskerdoo ri', 'ic overview', 'air compone', 'om acnm acc', ' centerline', 'e than any ', 'devotional ', 'de such dev']
# [' a']
# ['an']

# %%
def logprob(predictions, labels):
    """Log-probability of the true labels in a predicted batch."""
    predictions[predictions < 1e-10] = 1e-10
    return np.sum(np.multiply(labels, -np.log(predictions))) / labels.shape[0]

def sample_distribution(distribution):
    """Sample one element from a distribution assumed to be an array of normalized
    probabilities.
    """
    r = random.uniform(0, 1)
    s = 0
    for i in range(len(distribution)):
        s += distribution[i]
        if s >= r:
            return i
    return len(distribution) - 1

def sample(prediction):
    """Turn a (column) prediction into 1-hot encoded samples."""
    p = np.zeros(shape=[1, vocabulary_size], dtype=np.float)
    p[0, sample_distribution(prediction[0])] = 1.0
    return p

def random_distribution():
    """Generate a random column of probabilities."""
    b = np.random.uniform(0.0, 1.0, size=[1, vocabulary_size])
    return b/np.sum(b, 1)[:,None]

# %%
# Simple LSTM Model.
num_nodes = 64
graph = tf.Graph()
with graph.as_default():
    # Parameters:
    # Input gate: input, previous output, and bias.
    ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ib = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Forget gate: input, previous output, and bias.
    fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    fb = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Memory cell: input, state and bias.                             
    cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    cb = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Output gate: input, previous output, and bias.
    ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ob = tf.Variable(tf.zeros([1, num_nodes]))
  
    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        input_gate = tf.sigmoid(tf.matmul(i, ix) + tf.matmul(o, im) + ib)
        forget_gate = tf.sigmoid(tf.matmul(i, fx) + tf.matmul(o, fm) + fb)
        update = tf.matmul(i, cx) + tf.matmul(o, cm) + cb
        state = forget_gate * state + input_gate * tf.tanh(update)
        output_gate = tf.sigmoid(tf.matmul(i, ox) + tf.matmul(o, om) + ob)
        return output_gate * tf.tanh(state), state
    
    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.
    
    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)
    
    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(0,outputs), w, b)
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf.concat(0,train_labels)))
    
    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)
    
    # Predictions.
    train_prediction = tf.nn.softmax(logits)
    
    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(saved_sample_output.assign(tf.zeros([1, num_nodes])),
                                  saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(
    sample_input, saved_sample_output, saved_sample_state)
    
    with tf.control_dependencies([saved_sample_output.assign(sample_output),saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
        batches = train_batches.next()
        feed_dict = dict()
        for i in range(num_unrollings + 1):
            feed_dict[train_data[i]] = batches[i]
        _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        mean_loss += l
        if step % summary_frequency == 0:
            if step > 0:
                mean_loss = mean_loss / summary_frequency
            # The mean loss is an estimate of the loss over the last few batches.
            print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
            mean_loss = 0
            labels = np.concatenate(list(batches)[1:])
            print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
            if step % (summary_frequency * 10) == 0:
                # Generate some samples.
                print('=' * 80)
                for _ in range(5):
                    feed = sample(random_distribution())
                    sentence = characters(feed)[0]
                    reset_sample_state.run()
                    for _ in range(79):
                        prediction = sample_prediction.eval({sample_input: feed})
                        feed = sample(prediction)
                        sentence += characters(feed)[0]
                    print(sentence)
                print('=' * 80)
            # Measure validation set perplexity.
            reset_sample_state.run()
            valid_logprob = 0
            for _ in range(valid_size):
                b = valid_batches.next()
                predictions = sample_prediction.eval({sample_input: b[0]})
                valid_logprob = valid_logprob + logprob(predictions, b[1])
            print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.291541 learning rate: 10.000000
# Minibatch perplexity: 26.88
# ================================================================================
# ig ob  nfaeswnmzdtfzfpkbi t   n l a urt bmheyrfoe sivoexyomc fau ftukzaak sd it
# sdekeig  aeyrntfh asarrzvwvoa  gsyvorqynjrrg saslhn csptexyefesdefvsmaw kb anicy
# naeny npp q atehlyknvzmlj zaell iymr jba t h iqtleiqabv rvtqz b vxq h ywnwt r ti
# annajfudydl midajpeaeseu f mmjle qnrml   wsut xomr oavhmhgtea unoeewhwxnvnimn  s
# lfl ib oycrt zajaycfkterir ehuann qexeucpt zktdianu ntaut bss meaa ny t g ywu bh
# ================================================================================
# Validation set perplexity: 19.79
# Average loss at step 100: 2.605733 learning rate: 10.000000
# Minibatch perplexity: 11.92
# Validation set perplexity: 10.65
# Average loss at step 200: 2.277113 learning rate: 10.000000
# Minibatch perplexity: 8.04
# Validation set perplexity: 9.62
# Average loss at step 300: 2.112893 learning rate: 10.000000
# Minibatch perplexity: 7.85
# Validation set perplexity: 8.20
# Average loss at step 400: 2.036913 learning rate: 10.000000
# Minibatch perplexity: 7.04
# Validation set perplexity: 7.51
# Average loss at step 500: 1.955824 learning rate: 10.000000
# Minibatch perplexity: 6.81
# Validation set perplexity: 7.75
# Average loss at step 600: 1.899670 learning rate: 10.000000
# Minibatch perplexity: 6.12
# Validation set perplexity: 6.70
# Average loss at step 700: 1.863462 learning rate: 10.000000
# Minibatch perplexity: 6.26
# Validation set perplexity: 6.39
# Average loss at step 800: 1.848169 learning rate: 10.000000
# Minibatch perplexity: 6.55
# Validation set perplexity: 6.48
# Average loss at step 900: 1.802384 learning rate: 10.000000
# Minibatch perplexity: 6.16
# Validation set perplexity: 6.29
# Average loss at step 1000: 1.801693 learning rate: 10.000000
# Minibatch perplexity: 5.90
# ================================================================================
# da chantary in beetuare marly in marien in lumding in jostre tonated his war leg
# oriant rocome most the fremen the rechictic gisher vead har sen wordely the infi
# ughtion dbxings evernican bopobect hob brow write ar inip seswory crecrres the p
# ing it the tornal huld ientided plage authout we fsamay are in y s the reapled h
# bleenes tyrn to u dral shee io kaniectionsiins on deovires amen mice and dasid o
# ================================================================================
# Validation set perplexity: 5.97
# Average loss at step 1100: 1.805102 learning rate: 10.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 6.10
# Average loss at step 1200: 1.792095 learning rate: 10.000000
# Minibatch perplexity: 5.89
# Validation set perplexity: 6.11
# Average loss at step 1300: 1.787070 learning rate: 10.000000
# Minibatch perplexity: 5.75
# Validation set perplexity: 5.89
# Average loss at step 1400: 1.754227 learning rate: 10.000000
# Minibatch perplexity: 5.42
# Validation set perplexity: 5.68
# Average loss at step 1500: 1.753597 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 5.54
# Average loss at step 1600: 1.748690 learning rate: 10.000000
# Minibatch perplexity: 6.20
# Validation set perplexity: 5.67
# Average loss at step 1700: 1.745822 learning rate: 10.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 5.62
# Average loss at step 1800: 1.727377 learning rate: 10.000000
# Minibatch perplexity: 5.77
# Validation set perplexity: 5.48
# Average loss at step 1900: 1.731698 learning rate: 10.000000
# Minibatch perplexity: 5.52
# Validation set perplexity: 5.33
# Average loss at step 2000: 1.699237 learning rate: 10.000000
# Minibatch perplexity: 5.02
# ================================================================================
# ke and the frides of a one four eight engrion hither lidional oras plane from ki
# gastics mess with gound had to decome a shilss bionth the marious the flontist f
# ol a nampes of play his years rure harr one six andes inclide all dubrel serman
# ensely mahuess hould the mict at is stact hours from ona rach from the mookicle
# ber one nine eight two tha one five venole sthe was axaid the duivoms dispounde
# ================================================================================
# Validation set perplexity: 5.38
# Average loss at step 2100: 1.684948 learning rate: 10.000000
# Minibatch perplexity: 4.95
# Validation set perplexity: 5.13
# Average loss at step 2200: 1.688305 learning rate: 10.000000
# Minibatch perplexity: 5.81
# Validation set perplexity: 5.29
# Average loss at step 2300: 1.671810 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 5.18
# Average loss at step 2400: 1.696713 learning rate: 10.000000
# Minibatch perplexity: 5.54
# Validation set perplexity: 5.26
# Average loss at step 2500: 1.695785 learning rate: 10.000000
# Minibatch perplexity: 5.78
# Validation set perplexity: 5.15
# Average loss at step 2600: 1.680630 learning rate: 10.000000
# Minibatch perplexity: 6.10
# Validation set perplexity: 4.96
# Average loss at step 2700: 1.701947 learning rate: 10.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 5.24
# Average loss at step 2800: 1.684727 learning rate: 10.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 5.05
# Average loss at step 2900: 1.672047 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 4.96
# Average loss at step 3000: 1.648366 learning rate: 10.000000
# Minibatch perplexity: 5.18
# ================================================================================
# s in myres for burtaricle it are vasietres th engluse in one eight zero four eng
# wing air fory also anewiswead domation of hollfied sethnedted inceepenms bone ta
# dadly and syorica in etcanse perlink contrassia word einforts rpipicul roduc sho
# hads famclath callity muided theil univedia both obferd in the eperates alto and
#  runing the dirdvain on thomen these though where one nine eight sha nish epiled
# ================================================================================
# Validation set perplexity: 4.88
# Average loss at step 3100: 1.642853 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 4.91
# Average loss at step 3200: 1.630627 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 4.91
# Average loss at step 3300: 1.643037 learning rate: 10.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 5.02
# Average loss at step 3400: 1.649676 learning rate: 10.000000
# Minibatch perplexity: 6.11
# Validation set perplexity: 5.09
# Average loss at step 3500: 1.642861 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 4.99
# Average loss at step 3600: 1.655698 learning rate: 10.000000
# Minibatch perplexity: 5.00
# Validation set perplexity: 5.06
# Average loss at step 3700: 1.628284 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 4.84
# Average loss at step 3800: 1.631567 learning rate: 10.000000
# Minibatch perplexity: 5.74
# Validation set perplexity: 4.90
# Average loss at step 3900: 1.643122 learning rate: 10.000000
# Minibatch perplexity: 5.33
# Validation set perplexity: 4.94
# Average loss at step 4000: 1.620064 learning rate: 10.000000
# Minibatch perplexity: 5.07
# ================================================================================
# mor geolgitachicsion nine and road ufflu speciesly wetke are as cult list and be
# jomotism currentrant gaingest potlelle seapham the souraias comnicial of bulongi
# man the cannaukions of jaruane wosly that the periors that esperiby s one nine o
# mentedstoun regbo phonic of power suspolan mattrian lose this shour and egain it
# kz b two hester and adegbach coally commanatic was the played fow the samily ver
# ================================================================================
# Validation set perplexity: 4.90
# Average loss at step 4100: 1.616619 learning rate: 10.000000
# Minibatch perplexity: 4.94
# Validation set perplexity: 5.03
# Average loss at step 4200: 1.633768 learning rate: 10.000000
# Minibatch perplexity: 5.57
# Validation set perplexity: 5.09
# Average loss at step 4300: 1.619881 learning rate: 10.000000
# Minibatch perplexity: 5.37
# Validation set perplexity: 4.91
# Average loss at step 4400: 1.616035 learning rate: 10.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.88
# Average loss at step 4500: 1.595492 learning rate: 10.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 4.75
# Average loss at step 4600: 1.597896 learning rate: 10.000000
# Minibatch perplexity: 5.14
# Validation set perplexity: 4.68
# Average loss at step 4700: 1.626180 learning rate: 10.000000
# Minibatch perplexity: 4.41
# Validation set perplexity: 4.76
# Average loss at step 4800: 1.603397 learning rate: 10.000000
# Minibatch perplexity: 5.07
# Validation set perplexity: 4.72
# Average loss at step 4900: 1.606601 learning rate: 10.000000
# Minibatch perplexity: 4.92
# Validation set perplexity: 4.84
# Average loss at step 5000: 1.602828 learning rate: 1.000000
# Minibatch perplexity: 5.27
# ================================================================================
# ys suppofors in halls detylon decidube was poleus no ten or yor praces of first
# jessed the origatifics one seven seven he weal dissulent meased l nulanciea cloi
# ficing the innects but ul namie about an euch iumber moid was been was convert b
# has confort follieting eight nine four suculals kohn alwing they neature shy abo
# ted her onh goxer three billy quary needyh about a was a soek he have by traditt
# ================================================================================
# Validation set perplexity: 4.82
# Average loss at step 5100: 1.590304 learning rate: 1.000000
# Minibatch perplexity: 4.91
# Validation set perplexity: 4.66
# Average loss at step 5200: 1.587060 learning rate: 1.000000
# Minibatch perplexity: 4.40
# Validation set perplexity: 4.65
# Average loss at step 5300: 1.587676 learning rate: 1.000000
# Minibatch perplexity: 4.89
# Validation set perplexity: 4.64
# Average loss at step 5400: 1.543443 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.61
# Average loss at step 5500: 1.592371 learning rate: 1.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 4.60
# Average loss at step 5600: 1.577427 learning rate: 1.000000
# Minibatch perplexity: 4.78
# Validation set perplexity: 4.58
# Average loss at step 5700: 1.574928 learning rate: 1.000000
# Minibatch perplexity: 4.81
# Validation set perplexity: 4.60
# Average loss at step 5800: 1.567959 learning rate: 1.000000
# Minibatch perplexity: 5.08
# Validation set perplexity: 4.58
# Average loss at step 5900: 1.576651 learning rate: 1.000000
# Minibatch perplexity: 4.46
# Validation set perplexity: 4.55
# Average loss at step 6000: 1.590527 learning rate: 1.000000
# Minibatch perplexity: 4.47
# ================================================================================
# isan early dreed wrino remologion veticish court  toh brect for exus exelvent ou
# lyo of advie that welk bregarist the neconome the this thus to decoses not most
# s lathod brack s alternithen the only in junerel p buthr wardies euro iugolia an
# g the electuations it wasentian or mory memation to divic drowal admines languag
# over chanranguage one eight one beldenal singlesing complies to the poosetives c
# ================================================================================
# Validation set perplexity: 4.55
# Average loss at step 6100: 1.592186 learning rate: 1.000000
# Minibatch perplexity: 4.44
# Validation set perplexity: 4.53
# Average loss at step 6200: 1.547373 learning rate: 1.000000
# Minibatch perplexity: 4.42
# Validation set perplexity: 4.51
# Average loss at step 6300: 1.559563 learning rate: 1.000000
# Minibatch perplexity: 4.49
# Validation set perplexity: 4.52
# Average loss at step 6400: 1.594735 learning rate: 1.000000
# Minibatch perplexity: 5.10
# Validation set perplexity: 4.51
# Average loss at step 6500: 1.572977 learning rate: 1.000000
# Minibatch perplexity: 5.15
# Validation set perplexity: 4.51
# Average loss at step 6600: 1.579401 learning rate: 1.000000
# Minibatch perplexity: 4.20
# Validation set perplexity: 4.50
# Average loss at step 6700: 1.593890 learning rate: 1.000000
# Minibatch perplexity: 4.79
# Validation set perplexity: 4.50
# Average loss at step 6800: 1.607475 learning rate: 1.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.48
# Average loss at step 6900: 1.558346 learning rate: 1.000000
# Minibatch perplexity: 4.54
# Validation set perplexity: 4.50
# Average loss at step 7000: 1.535446 learning rate: 1.000000
# Minibatch perplexity: 4.74
# ================================================================================
# ze exminues and reperses one nine five zero beronists equeplomil in the drawable
# er of morallys they released from abrows sajoctary they land clate taxika zaro f
# x bargal at the simple under hararg to this technory to westers po reverse the f
# illo nwo though at carlers way suraffect in of headiars world bask one eight nin
# er the literst in which to disapport in the yearhy up with at the reveffire wo v
# ================================================================================
# Validation set perplexity: 4.51

# %%
# Problem 1
# You might have noticed that the definition of the LSTM cell involves 4 matrix multiplications
# with the input, and 4 matrix multiplications with the output. Simplify the expression by using 
# a single matrix multiply for each, and variables that are 4 times larger.

num_nodes = 64

graph = tf.Graph()
with graph.as_default():
    # Parameters:
    # Input gate: input, previous output, and bias.
    ix = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    im = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ib = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Forget gate: input, previous output, and bias.
    fx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    fm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    fb = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Memory cell: input, state and bias.                             
    cx = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    cm = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    cb = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Output gate: input, previous output, and bias.
    ox = tf.Variable(tf.truncated_normal([vocabulary_size, num_nodes], -0.1, 0.1))
    om = tf.Variable(tf.truncated_normal([num_nodes, num_nodes], -0.1, 0.1))
    ob = tf.Variable(tf.zeros([1, num_nodes]))
    
    # Concatenate parameters  
    sx = tf.concat(1, [ix, fx, cx, ox])
    sm = tf.concat(1, [im, fm, cm, om])
    sb = tf.concat(1, [ib, fb, cb, ob])
    
    # Variables saving state across unrollings.
    saved_output = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    saved_state = tf.Variable(tf.zeros([batch_size, num_nodes]), trainable=False)
    
    # Classifier weights and biases.
    w = tf.Variable(tf.truncated_normal([num_nodes, vocabulary_size], -0.1, 0.1))
    b = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Definition of the cell computation.
    def lstm_cell(i, o, state):
        """Create a LSTM cell. See e.g.: http://arxiv.org/pdf/1402.1128v1.pdf
        Note that in this formulation, we omit the various connections between the
        previous state and the gates."""
        smatmul = tf.matmul(i, sx) + tf.matmul(o, sm) + sb
        smatmul_input, smatmul_forget, update, smatmul_output = tf.split(1, 4, smatmul)
        input_gate = tf.sigmoid(smatmul_input)
        forget_gate = tf.sigmoid(smatmul_forget)
        output_gate = tf.sigmoid(smatmul_output)
        state = forget_gate * state + input_gate * tf.tanh(update)
        return output_gate * tf.tanh(state), state
    
    # Input data.
    train_data = list()
    for _ in range(num_unrollings + 1):
        train_data.append(tf.placeholder(tf.float32, shape=[batch_size,vocabulary_size]))
    train_inputs = train_data[:num_unrollings]
    train_labels = train_data[1:]  # labels are inputs shifted by one time step.

    # Unrolled LSTM loop.
    outputs = list()
    output = saved_output
    state = saved_state
    for i in train_inputs:
        output, state = lstm_cell(i, output, state)
        outputs.append(output)
        
    # State saving across unrollings.
    with tf.control_dependencies([saved_output.assign(output),saved_state.assign(state)]):
        # Classifier.
        logits = tf.nn.xw_plus_b(tf.concat(0, outputs), w, b)
        loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits, tf.concat(0, train_labels)))
        
    # Optimizer.
    global_step = tf.Variable(0)
    learning_rate = tf.train.exponential_decay(10.0, global_step, 5000, 0.1, staircase=True)
    optimizer = tf.train.GradientDescentOptimizer(learning_rate)
    gradients, v = zip(*optimizer.compute_gradients(loss))
    gradients, _ = tf.clip_by_global_norm(gradients, 1.25)
    optimizer = optimizer.apply_gradients(zip(gradients, v), global_step=global_step)
    
    # Predictions.
    train_prediction = tf.nn.softmax(logits)
    
    # Sampling and validation eval: batch 1, no unrolling.
    sample_input = tf.placeholder(tf.float32, shape=[1, vocabulary_size])
    saved_sample_output = tf.Variable(tf.zeros([1, num_nodes]))
    saved_sample_state = tf.Variable(tf.zeros([1, num_nodes]))
    reset_sample_state = tf.group(saved_sample_output.assign(tf.zeros([1, num_nodes])),
                                  saved_sample_state.assign(tf.zeros([1, num_nodes])))
    sample_output, sample_state = lstm_cell(sample_input, saved_sample_output, saved_sample_state)
    
    with tf.control_dependencies([saved_sample_output.assign(sample_output),saved_sample_state.assign(sample_state)]):
        sample_prediction = tf.nn.softmax(tf.nn.xw_plus_b(sample_output, w, b))

# %%
num_steps = 7001
summary_frequency = 100

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    mean_loss = 0
    for step in range(num_steps):
        batches = train_batches.next()
        feed_dict = dict()
        for i in range(num_unrollings + 1):
            feed_dict[train_data[i]] = batches[i]
        _, l, predictions, lr = session.run([optimizer, loss, train_prediction, learning_rate], feed_dict=feed_dict)
        mean_loss += l
        if step % summary_frequency == 0:
            if step > 0:
                mean_loss = mean_loss / summary_frequency
            # The mean loss is an estimate of the loss over the last few batches.
            print('Average loss at step %d: %f learning rate: %f' % (step, mean_loss, lr))
            mean_loss = 0
            labels = np.concatenate(list(batches)[1:])
            print('Minibatch perplexity: %.2f' % float(np.exp(logprob(predictions, labels))))
            if step % (summary_frequency * 10) == 0:
                # Generate some samples.
                print('=' * 80)
                for _ in range(5):
                    feed = sample(random_distribution())
                    sentence = characters(feed)[0]
                    reset_sample_state.run()
                    for _ in range(79):
                        prediction = sample_prediction.eval({sample_input: feed})
                        feed = sample(prediction)
                        sentence += characters(feed)[0]
                    print(sentence)
                print('=' * 80)
            # Measure validation set perplexity.
            reset_sample_state.run()
            valid_logprob = 0
            for _ in range(valid_size):
                b = valid_batches.next()
                predictions = sample_prediction.eval({sample_input: b[0]})
                valid_logprob = valid_logprob + logprob(predictions, b[1])
            print('Validation set perplexity: %.2f' % float(np.exp(valid_logprob / valid_size)))
# Out:
# Initialized
# Average loss at step 0: 3.292214 learning rate: 10.000000
# Minibatch perplexity: 26.90
# ================================================================================
# pg gnnt ht vr svinifowdirjcndnuguy venori z e j hele qerybz qnk zpeeub bmsif sj
# hlieha a wrcff  n ev nu b  dyk oeqaagw rcbsds eoh aboyqgek gege vz igmtn jr  dwr
# tjo r unmage u qtd bdaagxeetqfaxstt av cveceodlptn bbcxtrrcueed rhto as t vgti k
# va ao  nrfnbwc qbfgfnktelp edpmlg stfxaeinite j d vbvxtnn del csosnkvy jocttstne
# xieziyrr et bdiotsetiaef lnrrbrdxzqw tiqnrypme hdi ker ltkixexwnri  jzogaai yeow
# ================================================================================
# Validation set perplexity: 19.86
# Average loss at step 100: 2.612286 learning rate: 10.000000
# Minibatch perplexity: 10.66
# Validation set perplexity: 10.38
# Average loss at step 200: 2.275421 learning rate: 10.000000
# Minibatch perplexity: 9.79
# Validation set perplexity: 9.49
# Average loss at step 300: 2.092177 learning rate: 10.000000
# Minibatch perplexity: 7.75
# Validation set perplexity: 8.36
# Average loss at step 400: 2.022318 learning rate: 10.000000
# Minibatch perplexity: 6.51
# Validation set perplexity: 7.55
# Average loss at step 500: 1.936146 learning rate: 10.000000
# Minibatch perplexity: 6.60
# Validation set perplexity: 7.15
# Average loss at step 600: 1.922408 learning rate: 10.000000
# Minibatch perplexity: 7.75
# Validation set perplexity: 7.00
# Average loss at step 700: 1.883114 learning rate: 10.000000
# Minibatch perplexity: 6.27
# Validation set perplexity: 6.72
# Average loss at step 800: 1.857215 learning rate: 10.000000
# Minibatch perplexity: 5.63
# Validation set perplexity: 6.38
# Average loss at step 900: 1.822849 learning rate: 10.000000
# Minibatch perplexity: 6.39
# Validation set perplexity: 6.57
# Average loss at step 1000: 1.826627 learning rate: 10.000000
# Minibatch perplexity: 5.73
# ================================================================================
# zelo def dopew the often and the themect one nine vede foun high bane ay hish eb
# owing nat laykearra onew one nine zero zero inth the wink refelt one ninenen hin
# est fite that sovemoqanosef un a seiel to be frebses emil fici amerent for chase
# hiis e renived in piected naw laution have etherate aliath winderedc thistood be
# dy namhes bainigy the chiluten endasianalips adrectsliteded riseaw betore hleas
# ================================================================================
# Validation set perplexity: 6.21
# Average loss at step 1100: 1.775365 learning rate: 10.000000
# Minibatch perplexity: 5.92
# Validation set perplexity: 6.28
# Average loss at step 1200: 1.780032 learning rate: 10.000000
# Minibatch perplexity: 6.06
# Validation set perplexity: 6.25
# Average loss at step 1300: 1.756307 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 5.95
# Average loss at step 1400: 1.772530 learning rate: 10.000000
# Minibatch perplexity: 5.32
# Validation set perplexity: 6.03
# Average loss at step 1500: 1.747519 learning rate: 10.000000
# Minibatch perplexity: 5.39
# Validation set perplexity: 6.10
# Average loss at step 1600: 1.759024 learning rate: 10.000000
# Minibatch perplexity: 5.58
# Validation set perplexity: 5.90
# Average loss at step 1700: 1.717369 learning rate: 10.000000
# Minibatch perplexity: 5.25
# Validation set perplexity: 5.81
# Average loss at step 1800: 1.709058 learning rate: 10.000000
# Minibatch perplexity: 4.77
# Validation set perplexity: 5.77
# Average loss at step 1900: 1.698313 learning rate: 10.000000
# Minibatch perplexity: 5.85
# Validation set perplexity: 5.60
# Average loss at step 2000: 1.720455 learning rate: 10.000000
# Minibatch perplexity: 4.84
# ================================================================================
# jar yeiter in oor five but let theighov infreved hoach one whize ge balling the
# que by live rabled spezioses one nine eight new d smaletion a prather leax ester
# s or peoplation popt one creat clame of was have in the firsts babferic accessif
# ouras one nine eight the with one one zero nine obst for paysed in the sarter wi
# gue one would one zero one seven six to one zero zero seven thhe later to arpor
# ================================================================================
# Validation set perplexity: 5.41
# Average loss at step 2100: 1.683143 learning rate: 10.000000
# Minibatch perplexity: 5.62
# Validation set perplexity: 5.15
# Average loss at step 2200: 1.680719 learning rate: 10.000000
# Minibatch perplexity: 5.24
# Validation set perplexity: 5.29
# Average loss at step 2300: 1.678752 learning rate: 10.000000
# Minibatch perplexity: 5.20
# Validation set perplexity: 5.30
# Average loss at step 2400: 1.676984 learning rate: 10.000000
# Minibatch perplexity: 4.71
# Validation set perplexity: 5.33
# Average loss at step 2500: 1.655947 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 5.36
# Average loss at step 2600: 1.664631 learning rate: 10.000000
# Minibatch perplexity: 5.44
# Validation set perplexity: 5.28
# Average loss at step 2700: 1.659127 learning rate: 10.000000
# Minibatch perplexity: 5.69
# Validation set perplexity: 5.19
# Average loss at step 2800: 1.646098 learning rate: 10.000000
# Minibatch perplexity: 6.05
# Validation set perplexity: 5.09
# Average loss at step 2900: 1.647895 learning rate: 10.000000
# Minibatch perplexity: 4.99
# Validation set perplexity: 5.08
# Average loss at step 3000: 1.643409 learning rate: 10.000000
# Minibatch perplexity: 4.87
# ================================================================================
# ficall takest two zero five five number in math k il roye the bard a breest but
# terated humords and caman after finger well the impryctured predicted for has ce
# rark off afted have oreh both sove one one nine eight dossingsine one rusegue b
# x two knine greef carralom agee s soundidia often can soon laysion traish alst o
# f of would attermits the more state tatters in the war one nine eight zeron of b
# ================================================================================
# Validation set perplexity: 5.32
# Average loss at step 3100: 1.645527 learning rate: 10.000000
# Minibatch perplexity: 4.83
# Validation set perplexity: 5.22
# Average loss at step 3200: 1.622645 learning rate: 10.000000
# Minibatch perplexity: 4.44
# Validation set perplexity: 5.32
# Average loss at step 3300: 1.619397 learning rate: 10.000000
# Minibatch perplexity: 5.41
# Validation set perplexity: 5.12
# Average loss at step 3400: 1.655723 learning rate: 10.000000
# Minibatch perplexity: 5.35
# Validation set perplexity: 5.15
# Average loss at step 3500: 1.656930 learning rate: 10.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 5.25
# Average loss at step 3600: 1.620287 learning rate: 10.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 5.09
# Average loss at step 3700: 1.607291 learning rate: 10.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 5.16
# Average loss at step 3800: 1.613236 learning rate: 10.000000
# Minibatch perplexity: 4.60
# Validation set perplexity: 5.01
# Average loss at step 3900: 1.632648 learning rate: 10.000000
# Minibatch perplexity: 4.70
# Validation set perplexity: 5.09
# Average loss at step 4000: 1.647389 learning rate: 10.000000
# Minibatch perplexity: 5.07
# ================================================================================
# d progoms six colleption of alliogate of film and tasivess argumed is nure in th
# mal some been polys wit plarg champeans are book hundoung of whrood are of the r
# idg rudar coptacied machoolts king the bas world te the moberals of revice to mo
#  eldemition rated of explased in two nine nureids two zines has desaareted had p
# thartilait oreced the piomican his by lodement medger parteed all known for five
# ================================================================================
# Validation set perplexity: 5.02
# Average loss at step 4100: 1.665366 learning rate: 10.000000
# Minibatch perplexity: 5.79
# Validation set perplexity: 5.09
# Average loss at step 4200: 1.621166 learning rate: 10.000000
# Minibatch perplexity: 5.54
# Validation set perplexity: 5.03
# Average loss at step 4300: 1.623011 learning rate: 10.000000
# Minibatch perplexity: 5.06
# Validation set perplexity: 4.96
# Average loss at step 4400: 1.607916 learning rate: 10.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.97
# Average loss at step 4500: 1.632065 learning rate: 10.000000
# Minibatch perplexity: 5.21
# Validation set perplexity: 4.78
# Average loss at step 4600: 1.601324 learning rate: 10.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.91
# Average loss at step 4700: 1.604099 learning rate: 10.000000
# Minibatch perplexity: 4.55
# Validation set perplexity: 4.96
# Average loss at step 4800: 1.607062 learning rate: 10.000000
# Minibatch perplexity: 5.66
# Validation set perplexity: 5.01
# Average loss at step 4900: 1.583571 learning rate: 10.000000
# Minibatch perplexity: 5.40
# Validation set perplexity: 5.05
# Average loss at step 5000: 1.596787 learning rate: 1.000000
# Minibatch perplexity: 4.61
# ================================================================================
# us ff making the xbarms was propope of ubiving state formed the juck and spo as
# s a german as commoning mand the ramed booklis the folmed axwilliam s hauls was
# ger remactors to a several cased of prohicict and letweenson score chires was in
# s such any to the poctrred in net from one eight s qud coulahues highly showever
# zing this now radion entilelleded to comethisted similar of drfaction of extende
# ================================================================================
# Validation set perplexity: 4.97
# Average loss at step 5100: 1.591028 learning rate: 1.000000
# Minibatch perplexity: 4.67
# Validation set perplexity: 4.83
# Average loss at step 5200: 1.620304 learning rate: 1.000000
# Minibatch perplexity: 4.88
# Validation set perplexity: 4.82
# Average loss at step 5300: 1.634408 learning rate: 1.000000
# Minibatch perplexity: 5.23
# Validation set perplexity: 4.75
# Average loss at step 5400: 1.643985 learning rate: 1.000000
# Minibatch perplexity: 4.50
# Validation set perplexity: 4.71
# Average loss at step 5500: 1.618414 learning rate: 1.000000
# Minibatch perplexity: 4.72
# Validation set perplexity: 4.71
# Average loss at step 5600: 1.587074 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.72
# Average loss at step 5700: 1.590846 learning rate: 1.000000
# Minibatch perplexity: 4.61
# Validation set perplexity: 4.72
# Average loss at step 5800: 1.565595 learning rate: 1.000000
# Minibatch perplexity: 4.73
# Validation set perplexity: 4.71
# Average loss at step 5900: 1.594972 learning rate: 1.000000
# Minibatch perplexity: 4.25
# Validation set perplexity: 4.69
# Average loss at step 6000: 1.553800 learning rate: 1.000000
# Minibatch perplexity: 4.84
# ================================================================================
# dual or unamonting west list keborch operatas as belioulg of the pale premivativ
# jose s one the recroes carlow of lem conso skilwho peities forluca hod a books a
# y there exwerrence basquess analge effects popratts opbania six partia s purmon
# zel iclear primate power of one nine eight two los considering tacu and stroden
# pilinate of emituated s american thaid two paray of linishevely moneable kn hes
# ================================================================================
# Validation set perplexity: 4.66
# Average loss at step 6100: 1.591448 learning rate: 1.000000
# Minibatch perplexity: 5.18
# Validation set perplexity: 4.68
# Average loss at step 6200: 1.600928 learning rate: 1.000000
# Minibatch perplexity: 4.82
# Validation set perplexity: 4.65
# Average loss at step 6300: 1.588244 learning rate: 1.000000
# Minibatch perplexity: 4.69
# Validation set perplexity: 4.59
# Average loss at step 6400: 1.571882 learning rate: 1.000000
# Minibatch perplexity: 4.96
# Validation set perplexity: 4.59
# Average loss at step 6500: 1.583649 learning rate: 1.000000
# Minibatch perplexity: 4.66
# Validation set perplexity: 4.57
# Average loss at step 6600: 1.570091 learning rate: 1.000000
# Minibatch perplexity: 4.68
# Validation set perplexity: 4.56
# Average loss at step 6700: 1.582566 learning rate: 1.000000
# Minibatch perplexity: 4.75
# Validation set perplexity: 4.52
# Average loss at step 6800: 1.591942 learning rate: 1.000000
# Minibatch perplexity: 5.83
# Validation set perplexity: 4.50
# Average loss at step 6900: 1.573521 learning rate: 1.000000
# Minibatch perplexity: 4.22
# Validation set perplexity: 4.48
# Average loss at step 7000: 1.559930 learning rate: 1.000000
# Minibatch perplexity: 4.84
# ================================================================================
# x ofdays jon war best a ded his specy one rade formation are also becomes in the
# que add moter and frake as the ulting takess she is milultar of this max was fou
#  followar as the family he cansembiration to various one nine six units and holu
# vayed quefisin precegues and it aften time vines subsca the mituri subtess abera
# lim economistalization and angen on straid he dispire dvh sotia baid and america
# ================================================================================
# Validation set perplexity: 4.45
