# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
f = open('text8', "r")
words = tf.compat.as_str(f.read()).split()
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 200000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
print('Dictionary size: ', len(dictionary))
# Out:
# Most common words (+UNK) [['UNK', 53855], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3081, 12, 6, 195, 2, 3135, 46, 59, 156]
# Dictionary size:  200000

# %%
del words  # Hint to reduce memory.

# %%
# Function to generate a training batch for the skip-gram model.
data_index = 0
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'originated', 'a', 'term', 'as', 'of', 'term', 'originated']

# %%
# Train a skip-gram model.
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
'''
 We pick a random validation set to sample nearest neighbors. here we limit the
 validation samples to the words that have a low numeric ID, which by
 construction are also the most frequent. 
'''
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()
with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                                     train_labels, num_sampled, vocabulary_size))
    # Optimizer.
    ''' 
    Note: The optimizer will optimize the softmax_weights AND the embeddings.
    This is because the embeddings are defined as a variable quantity and the
    optimizer's `minimize` method will by default modify all variable quantities 
    that contribute to the tensor it is passed.
    See docs on `tf.train.Optimizer.minimize()` for more details.
    '''
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                    print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.903065
# Nearest to more: cksb,
# Nearest to more: cksb, salih,
# Nearest to more: cksb, salih, dunmore,
# Nearest to more: cksb, salih, dunmore, mtsho,
# Nearest to more: cksb, salih, dunmore, mtsho, fauxjito,
# Nearest to more: cksb, salih, dunmore, mtsho, fauxjito, inertiae,
# Nearest to more: cksb, salih, dunmore, mtsho, fauxjito, inertiae, vaghela,
# Nearest to more: cksb, salih, dunmore, mtsho, fauxjito, inertiae, vaghela, inmarsat,
# Nearest to in: lsbu,
# Nearest to in: lsbu, beavan,
# Nearest to in: lsbu, beavan, broken,
# Nearest to in: lsbu, beavan, broken, nun,
# Nearest to in: lsbu, beavan, broken, nun, kashinath,
# Nearest to in: lsbu, beavan, broken, nun, kashinath, tent,
# Nearest to in: lsbu, beavan, broken, nun, kashinath, tent, leqa,
# Nearest to in: lsbu, beavan, broken, nun, kashinath, tent, leqa, desire,
# Nearest to at: arctoidea,
# Nearest to at: arctoidea, relyed,
# Nearest to at: arctoidea, relyed, salamines,
# Nearest to at: arctoidea, relyed, salamines, lorca,
# Nearest to at: arctoidea, relyed, salamines, lorca, daithi,
# Nearest to at: arctoidea, relyed, salamines, lorca, daithi, khaimah,
# Nearest to at: arctoidea, relyed, salamines, lorca, daithi, khaimah, bianciotto,
# Nearest to at: arctoidea, relyed, salamines, lorca, daithi, khaimah, bianciotto, submillimeter,
# Nearest to be: functionname,
# Nearest to be: functionname, moca,
# Nearest to be: functionname, moca, mistook,
# Nearest to be: functionname, moca, mistook, stalactites,
# Nearest to be: functionname, moca, mistook, stalactites, positives,
# Nearest to be: functionname, moca, mistook, stalactites, positives, leech,
# Nearest to be: functionname, moca, mistook, stalactites, positives, leech, blocking,
# Nearest to be: functionname, moca, mistook, stalactites, positives, leech, blocking, ornithopter,
# Nearest to six: pyroelectric,
# Nearest to six: pyroelectric, angustissima,
# Nearest to six: pyroelectric, angustissima, corrin,
# Nearest to six: pyroelectric, angustissima, corrin, outranking,
# Nearest to six: pyroelectric, angustissima, corrin, outranking, eucharistically,
# Nearest to six: pyroelectric, angustissima, corrin, outranking, eucharistically, glutaraldehyde,
# Nearest to six: pyroelectric, angustissima, corrin, outranking, eucharistically, glutaraldehyde, subthalamus,
# Nearest to six: pyroelectric, angustissima, corrin, outranking, eucharistically, glutaraldehyde, subthalamus, intangibles,
# Nearest to use: ishgn,
# Nearest to use: ishgn, mazi,
# Nearest to use: ishgn, mazi, restauration,
# Nearest to use: ishgn, mazi, restauration, wedmore,
# Nearest to use: ishgn, mazi, restauration, wedmore, induce,
# Nearest to use: ishgn, mazi, restauration, wedmore, induce, sarid,
# Nearest to use: ishgn, mazi, restauration, wedmore, induce, sarid, justicia,
# Nearest to use: ishgn, mazi, restauration, wedmore, induce, sarid, justicia, bunsen,
# Nearest to i: thoil,
# Nearest to i: thoil, ashahel,
# Nearest to i: thoil, ashahel, riboswitches,
# Nearest to i: thoil, ashahel, riboswitches, elasippus,
# Nearest to i: thoil, ashahel, riboswitches, elasippus, horne,
# Nearest to i: thoil, ashahel, riboswitches, elasippus, horne, sisters,
# Nearest to i: thoil, ashahel, riboswitches, elasippus, horne, sisters, ffp,
# Nearest to i: thoil, ashahel, riboswitches, elasippus, horne, sisters, ffp, kenyatta,
# Nearest to on: mecoptera,
# Nearest to on: mecoptera, agonal,
# Nearest to on: mecoptera, agonal, yehosua,
# Nearest to on: mecoptera, agonal, yehosua, mischmetal,
# Nearest to on: mecoptera, agonal, yehosua, mischmetal, projects,
# Nearest to on: mecoptera, agonal, yehosua, mischmetal, projects, neri,
# Nearest to on: mecoptera, agonal, yehosua, mischmetal, projects, neri, whitsunday,
# Nearest to on: mecoptera, agonal, yehosua, mischmetal, projects, neri, whitsunday, erets,
# Nearest to had: peponocephalia,
# Nearest to had: peponocephalia, hikaru,
# Nearest to had: peponocephalia, hikaru, scuffed,
# Nearest to had: peponocephalia, hikaru, scuffed, arsche,
# Nearest to had: peponocephalia, hikaru, scuffed, arsche, choropleth,
# Nearest to had: peponocephalia, hikaru, scuffed, arsche, choropleth, ananova,
# Nearest to had: peponocephalia, hikaru, scuffed, arsche, choropleth, ananova, kretser,
# Nearest to had: peponocephalia, hikaru, scuffed, arsche, choropleth, ananova, kretser, digitalized,
# Nearest to after: yoshinkai,
# Nearest to after: yoshinkai, osbourne,
# Nearest to after: yoshinkai, osbourne, painstakingly,
# Nearest to after: yoshinkai, osbourne, painstakingly, externalities,
# Nearest to after: yoshinkai, osbourne, painstakingly, externalities, naturschutzes,
# Nearest to after: yoshinkai, osbourne, painstakingly, externalities, naturschutzes, silverheels,
# Nearest to after: yoshinkai, osbourne, painstakingly, externalities, naturschutzes, silverheels, montiero,
# Nearest to after: yoshinkai, osbourne, painstakingly, externalities, naturschutzes, silverheels, montiero, horrific,
# Nearest to may: detour,
# Nearest to may: detour, jutes,
# Nearest to may: detour, jutes, liaising,
# Nearest to may: detour, jutes, liaising, voluerat,
# Nearest to may: detour, jutes, liaising, voluerat, thegrapesofwrathbookcover,
# Nearest to may: detour, jutes, liaising, voluerat, thegrapesofwrathbookcover, kikizi,
# Nearest to may: detour, jutes, liaising, voluerat, thegrapesofwrathbookcover, kikizi, dancesport,
# Nearest to may: detour, jutes, liaising, voluerat, thegrapesofwrathbookcover, kikizi, dancesport, descend,
# Nearest to were: storms,
# Nearest to were: storms, eigrp,
# Nearest to were: storms, eigrp, sondheimesque,
# Nearest to were: storms, eigrp, sondheimesque, kociewiacy,
# Nearest to were: storms, eigrp, sondheimesque, kociewiacy, dabh,
# Nearest to were: storms, eigrp, sondheimesque, kociewiacy, dabh, theologically,
# Nearest to were: storms, eigrp, sondheimesque, kociewiacy, dabh, theologically, elmwood,
# Nearest to were: storms, eigrp, sondheimesque, kociewiacy, dabh, theologically, elmwood, caatinga,
# Nearest to however: petropolitics,
# Nearest to however: petropolitics, prolongations,
# Nearest to however: petropolitics, prolongations, naked,
# Nearest to however: petropolitics, prolongations, naked, barnsley,
# Nearest to however: petropolitics, prolongations, naked, barnsley, manorial,
# Nearest to however: petropolitics, prolongations, naked, barnsley, manorial, savarin,
# Nearest to however: petropolitics, prolongations, naked, barnsley, manorial, savarin, somnambulists,
# Nearest to however: petropolitics, prolongations, naked, barnsley, manorial, savarin, somnambulists, ergebnisse,
# Nearest to when: titiwangsa,
# Nearest to when: titiwangsa, lexicalized,
# Nearest to when: titiwangsa, lexicalized, marinism,
# Nearest to when: titiwangsa, lexicalized, marinism, saprissa,
# Nearest to when: titiwangsa, lexicalized, marinism, saprissa, deca,
# Nearest to when: titiwangsa, lexicalized, marinism, saprissa, deca, homogenised,
# Nearest to when: titiwangsa, lexicalized, marinism, saprissa, deca, homogenised, mera,
# Nearest to when: titiwangsa, lexicalized, marinism, saprissa, deca, homogenised, mera, fines,
# Nearest to four: notley,
# Nearest to four: notley, schorr,
# Nearest to four: notley, schorr, malvales,
# Nearest to four: notley, schorr, malvales, bronchoscopy,
# Nearest to four: notley, schorr, malvales, bronchoscopy, mccurdy,
# Nearest to four: notley, schorr, malvales, bronchoscopy, mccurdy, crossdressers,
# Nearest to four: notley, schorr, malvales, bronchoscopy, mccurdy, crossdressers, gambia,
# Nearest to four: notley, schorr, malvales, bronchoscopy, mccurdy, crossdressers, gambia, haymanot,
# Nearest to history: busaco,
# Nearest to history: busaco, iodoxybenzoic,
# Nearest to history: busaco, iodoxybenzoic, bigger,
# Nearest to history: busaco, iodoxybenzoic, bigger, mesomelas,
# Nearest to history: busaco, iodoxybenzoic, bigger, mesomelas, correctness,
# Nearest to history: busaco, iodoxybenzoic, bigger, mesomelas, correctness, alcools,
# Nearest to history: busaco, iodoxybenzoic, bigger, mesomelas, correctness, alcools, influenza,
# Nearest to history: busaco, iodoxybenzoic, bigger, mesomelas, correctness, alcools, influenza, prune,
# Average loss at step 2000: 4.861096
# Average loss at step 4000: 4.158918
# Average loss at step 6000: 3.997963
# Average loss at step 8000: 3.848946
# Average loss at step 10000: 3.765558
# Nearest to more: inertiae,
# Nearest to more: inertiae, msc,
# Nearest to more: inertiae, msc, sawamatsu,
# Nearest to more: inertiae, msc, sawamatsu, petard,
# Nearest to more: inertiae, msc, sawamatsu, petard, vafthruthnismal,
# Nearest to more: inertiae, msc, sawamatsu, petard, vafthruthnismal, cernlib,
# Nearest to more: inertiae, msc, sawamatsu, petard, vafthruthnismal, cernlib, kauravas,
# Nearest to more: inertiae, msc, sawamatsu, petard, vafthruthnismal, cernlib, kauravas, kedarites,
# Nearest to in: of,
# Nearest to in: of, on,
# Nearest to in: of, on, at,
# Nearest to in: of, on, at, by,
# Nearest to in: of, on, at, by, with,
# Nearest to in: of, on, at, by, with, from,
# Nearest to in: of, on, at, by, with, from, and,
# Nearest to in: of, on, at, by, with, from, and, as,
# Nearest to at: in,
# Nearest to at: in, by,
# Nearest to at: in, by, optimo,
# Nearest to at: in, by, optimo, against,
# Nearest to at: in, by, optimo, against, almos,
# Nearest to at: in, by, optimo, against, almos, submillimeter,
# Nearest to at: in, by, optimo, against, almos, submillimeter, on,
# Nearest to at: in, by, optimo, against, almos, submillimeter, on, philadelphians,
# Nearest to be: have,
# Nearest to be: have, been,
# Nearest to be: have, been, diggory,
# Nearest to be: have, been, diggory, gharbiyya,
# Nearest to be: have, been, diggory, gharbiyya, fatuous,
# Nearest to be: have, been, diggory, gharbiyya, fatuous, lem,
# Nearest to be: have, been, diggory, gharbiyya, fatuous, lem, is,
# Nearest to be: have, been, diggory, gharbiyya, fatuous, lem, is, installerscompiled,
# Nearest to six: eight,
# Nearest to six: eight, seven,
# Nearest to six: eight, seven, three,
# Nearest to six: eight, seven, three, four,
# Nearest to six: eight, seven, three, four, five,
# Nearest to six: eight, seven, three, four, five, nine,
# Nearest to six: eight, seven, three, four, five, nine, zero,
# Nearest to six: eight, seven, three, four, five, nine, zero, two,
# Nearest to use: ishgn,
# Nearest to use: ishgn, terms,
# Nearest to use: ishgn, terms, mazi,
# Nearest to use: ishgn, terms, mazi, fabilli,
# Nearest to use: ishgn, terms, mazi, fabilli, carnival,
# Nearest to use: ishgn, terms, mazi, fabilli, carnival, restauration,
# Nearest to use: ishgn, terms, mazi, fabilli, carnival, restauration, foi,
# Nearest to use: ishgn, terms, mazi, fabilli, carnival, restauration, foi, emory,
# Nearest to i: unsandalled,
# Nearest to i: unsandalled, suntimes,
# Nearest to i: unsandalled, suntimes, johanssen,
# Nearest to i: unsandalled, suntimes, johanssen, atymnios,
# Nearest to i: unsandalled, suntimes, johanssen, atymnios, asteropeiaceae,
# Nearest to i: unsandalled, suntimes, johanssen, atymnios, asteropeiaceae, kenyatta,
# Nearest to i: unsandalled, suntimes, johanssen, atymnios, asteropeiaceae, kenyatta, thoil,
# Nearest to i: unsandalled, suntimes, johanssen, atymnios, asteropeiaceae, kenyatta, thoil, zokunihongi,
# Nearest to on: in,
# Nearest to on: in, by,
# Nearest to on: in, by, through,
# Nearest to on: in, by, through, pacific,
# Nearest to on: in, by, through, pacific, upon,
# Nearest to on: in, by, through, pacific, upon, mourns,
# Nearest to on: in, by, through, pacific, upon, mourns, hyz,
# Nearest to on: in, by, through, pacific, upon, mourns, hyz, wiggler,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, ladri,
# Nearest to had: has, have, was, ladri, tetramers,
# Nearest to had: has, have, was, ladri, tetramers, voiceofdance,
# Nearest to had: has, have, was, ladri, tetramers, voiceofdance, hikaru,
# Nearest to had: has, have, was, ladri, tetramers, voiceofdance, hikaru, kaliveli,
# Nearest to after: mananger,
# Nearest to after: mananger, by,
# Nearest to after: mananger, by, lighthouse,
# Nearest to after: mananger, by, lighthouse, sadcc,
# Nearest to after: mananger, by, lighthouse, sadcc, in,
# Nearest to after: mananger, by, lighthouse, sadcc, in, on,
# Nearest to after: mananger, by, lighthouse, sadcc, in, on, salinan,
# Nearest to after: mananger, by, lighthouse, sadcc, in, on, salinan, cyp,
# Nearest to may: can,
# Nearest to may: can, must,
# Nearest to may: can, must, would,
# Nearest to may: can, must, would, nibelung,
# Nearest to may: can, must, would, nibelung, kikizi,
# Nearest to may: can, must, would, nibelung, kikizi, schenkenberg,
# Nearest to may: can, must, would, nibelung, kikizi, schenkenberg, khiriq,
# Nearest to may: can, must, would, nibelung, kikizi, schenkenberg, khiriq, kawai,
# Nearest to were: are,
# Nearest to were: are, was,
# Nearest to were: are, was, is,
# Nearest to were: are, was, is, refrains,
# Nearest to were: are, was, is, refrains, storms,
# Nearest to were: are, was, is, refrains, storms, but,
# Nearest to were: are, was, is, refrains, storms, but, respectfully,
# Nearest to were: are, was, is, refrains, storms, but, respectfully, lagren,
# Nearest to however: somnambulists,
# Nearest to however: somnambulists, petropolitics,
# Nearest to however: somnambulists, petropolitics, and,
# Nearest to however: somnambulists, petropolitics, and, betio,
# Nearest to however: somnambulists, petropolitics, and, betio, subtyped,
# Nearest to however: somnambulists, petropolitics, and, betio, subtyped, incestuousness,
# Nearest to however: somnambulists, petropolitics, and, betio, subtyped, incestuousness, watta,
# Nearest to however: somnambulists, petropolitics, and, betio, subtyped, incestuousness, watta, savarin,
# Nearest to when: might,
# Nearest to when: might, proops,
# Nearest to when: might, proops, sacramental,
# Nearest to when: might, proops, sacramental, anthropogenically,
# Nearest to when: might, proops, sacramental, anthropogenically, barsoom,
# Nearest to when: might, proops, sacramental, anthropogenically, barsoom, reclaims,
# Nearest to when: might, proops, sacramental, anthropogenically, barsoom, reclaims, within,
# Nearest to when: might, proops, sacramental, anthropogenically, barsoom, reclaims, within, lexicalized,
# Nearest to four: three,
# Nearest to four: three, eight,
# Nearest to four: three, eight, six,
# Nearest to four: three, eight, six, seven,
# Nearest to four: three, eight, six, seven, five,
# Nearest to four: three, eight, six, seven, five, two,
# Nearest to four: three, eight, six, seven, five, two, nine,
# Nearest to four: three, eight, six, seven, five, two, nine, zero,
# Nearest to history: segregating,
# Nearest to history: segregating, grammatica,
# Nearest to history: segregating, grammatica, church,
# Nearest to history: segregating, grammatica, church, trichoptera,
# Nearest to history: segregating, grammatica, church, trichoptera, flexography,
# Nearest to history: segregating, grammatica, church, trichoptera, flexography, different,
# Nearest to history: segregating, grammatica, church, trichoptera, flexography, different, spline,
# Nearest to history: segregating, grammatica, church, trichoptera, flexography, different, spline, barley,
# Average loss at step 12000: 3.722230
# Average loss at step 14000: 3.684154
# Average loss at step 16000: 3.513457
# Average loss at step 18000: 3.541848
# Average loss at step 20000: 3.597241
# Nearest to more: less,
# Nearest to more: less, very,
# Nearest to more: less, very, sawamatsu,
# Nearest to more: less, very, sawamatsu, kauravas,
# Nearest to more: less, very, sawamatsu, kauravas, cernlib,
# Nearest to more: less, very, sawamatsu, kauravas, cernlib, most,
# Nearest to more: less, very, sawamatsu, kauravas, cernlib, most, skerping,
# Nearest to more: less, very, sawamatsu, kauravas, cernlib, most, skerping, jesti,
# Nearest to in: at,
# Nearest to in: at, on,
# Nearest to in: at, on, with,
# Nearest to in: at, on, with, from,
# Nearest to in: at, on, with, from, and,
# Nearest to in: at, on, with, from, and, throughout,
# Nearest to in: at, on, with, from, and, throughout, for,
# Nearest to in: at, on, with, from, and, throughout, for, geisengrund,
# Nearest to at: in,
# Nearest to at: in, on,
# Nearest to at: in, on, monuc,
# Nearest to at: in, on, monuc, almos,
# Nearest to at: in, on, monuc, almos, bianciotto,
# Nearest to at: in, on, monuc, almos, bianciotto, dinky,
# Nearest to at: in, on, monuc, almos, bianciotto, dinky, arab,
# Nearest to at: in, on, monuc, almos, bianciotto, dinky, arab, hainburg,
# Nearest to be: have,
# Nearest to be: have, been,
# Nearest to be: have, been, is,
# Nearest to be: have, been, is, being,
# Nearest to be: have, been, is, being, was,
# Nearest to be: have, been, is, being, was, colouration,
# Nearest to be: have, been, is, being, was, colouration, diggory,
# Nearest to be: have, been, is, being, was, colouration, diggory, baggio,
# Nearest to six: seven,
# Nearest to six: seven, eight,
# Nearest to six: seven, eight, four,
# Nearest to six: seven, eight, four, three,
# Nearest to six: seven, eight, four, three, five,
# Nearest to six: seven, eight, four, three, five, nine,
# Nearest to six: seven, eight, four, three, five, nine, two,
# Nearest to six: seven, eight, four, three, five, nine, two, zero,
# Nearest to use: order,
# Nearest to use: order, mazi,
# Nearest to use: order, mazi, terms,
# Nearest to use: order, mazi, terms, fabilli,
# Nearest to use: order, mazi, terms, fabilli, ixobrychus,
# Nearest to use: order, mazi, terms, fabilli, ixobrychus, emory,
# Nearest to use: order, mazi, terms, fabilli, ixobrychus, emory, cancaver,
# Nearest to use: order, mazi, terms, fabilli, ixobrychus, emory, cancaver, kowtow,
# Nearest to i: ii,
# Nearest to i: ii, unsandalled,
# Nearest to i: ii, unsandalled, johanssen,
# Nearest to i: ii, unsandalled, johanssen, asteropeiaceae,
# Nearest to i: ii, unsandalled, johanssen, asteropeiaceae, atymnios,
# Nearest to i: ii, unsandalled, johanssen, asteropeiaceae, atymnios, radiobeacon,
# Nearest to i: ii, unsandalled, johanssen, asteropeiaceae, atymnios, radiobeacon, sharq,
# Nearest to i: ii, unsandalled, johanssen, asteropeiaceae, atymnios, radiobeacon, sharq, kenyatta,
# Nearest to on: upon,
# Nearest to on: upon, in,
# Nearest to on: upon, in, through,
# Nearest to on: upon, in, through, at,
# Nearest to on: upon, in, through, at, during,
# Nearest to on: upon, in, through, at, during, managry,
# Nearest to on: upon, in, through, at, during, managry, by,
# Nearest to on: upon, in, through, at, during, managry, by, wiggler,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, were,
# Nearest to had: has, have, was, were, ladri,
# Nearest to had: has, have, was, were, ladri, having,
# Nearest to had: has, have, was, were, ladri, having, is,
# Nearest to had: has, have, was, were, ladri, having, is, lugdunum,
# Nearest to after: when,
# Nearest to after: when, from,
# Nearest to after: when, from, mananger,
# Nearest to after: when, from, mananger, eisai,
# Nearest to after: when, from, mananger, eisai, cicer,
# Nearest to after: when, from, mananger, eisai, cicer, cyp,
# Nearest to after: when, from, mananger, eisai, cicer, cyp, attaining,
# Nearest to after: when, from, mananger, eisai, cicer, cyp, attaining, creativecommons,
# Nearest to may: can,
# Nearest to may: can, would,
# Nearest to may: can, would, must,
# Nearest to may: can, would, must, could,
# Nearest to may: can, would, must, could, will,
# Nearest to may: can, would, must, could, will, should,
# Nearest to may: can, would, must, could, will, should, to,
# Nearest to may: can, would, must, could, will, should, to, might,
# Nearest to were: are,
# Nearest to were: are, was,
# Nearest to were: are, was, had,
# Nearest to were: are, was, had, have,
# Nearest to were: are, was, had, have, by,
# Nearest to were: are, was, had, have, by, franciscan,
# Nearest to were: are, was, had, have, by, franciscan, kalatehas,
# Nearest to were: are, was, had, have, by, franciscan, kalatehas, is,
# Nearest to however: but,
# Nearest to however: but, somnambulists,
# Nearest to however: but, somnambulists, petropolitics,
# Nearest to however: but, somnambulists, petropolitics, hartshorn,
# Nearest to however: but, somnambulists, petropolitics, hartshorn, diplomarbeit,
# Nearest to however: but, somnambulists, petropolitics, hartshorn, diplomarbeit, caved,
# Nearest to however: but, somnambulists, petropolitics, hartshorn, diplomarbeit, caved, since,
# Nearest to however: but, somnambulists, petropolitics, hartshorn, diplomarbeit, caved, since, betio,
# Nearest to when: where,
# Nearest to when: where, if,
# Nearest to when: where, if, after,
# Nearest to when: where, if, after, but,
# Nearest to when: where, if, after, but, that,
# Nearest to when: where, if, after, but, that, was,
# Nearest to when: where, if, after, but, that, was, again,
# Nearest to when: where, if, after, but, that, was, again, as,
# Nearest to four: three,
# Nearest to four: three, six,
# Nearest to four: three, six, five,
# Nearest to four: three, six, five, eight,
# Nearest to four: three, six, five, eight, seven,
# Nearest to four: three, six, five, eight, seven, two,
# Nearest to four: three, six, five, eight, seven, two, nine,
# Nearest to four: three, six, five, eight, seven, two, nine, one,
# Nearest to history: segregating,
# Nearest to history: segregating, grammatica,
# Nearest to history: segregating, grammatica, church,
# Nearest to history: segregating, grammatica, church, gambas,
# Nearest to history: segregating, grammatica, church, gambas, trichoptera,
# Nearest to history: segregating, grammatica, church, gambas, trichoptera, science,
# Nearest to history: segregating, grammatica, church, gambas, trichoptera, science, velma,
# Nearest to history: segregating, grammatica, church, gambas, trichoptera, science, velma, house,
# Average loss at step 22000: 3.558599
# Average loss at step 24000: 3.551985
# Average loss at step 26000: 3.541260
# Average loss at step 28000: 3.530493
# Average loss at step 30000: 3.554616
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, cernlib,
# Nearest to more: less, most, very, cernlib, longer,
# Nearest to more: less, most, very, cernlib, longer, longmont,
# Nearest to more: less, most, very, cernlib, longer, longmont, sawamatsu,
# Nearest to more: less, most, very, cernlib, longer, longmont, sawamatsu, rongzhen,
# Nearest to in: at,
# Nearest to in: at, during,
# Nearest to in: at, during, on,
# Nearest to in: at, during, on, of,
# Nearest to in: at, during, on, of, between,
# Nearest to in: at, during, on, of, between, from,
# Nearest to in: at, during, on, of, between, from, and,
# Nearest to in: at, during, on, of, between, from, and, throughout,
# Nearest to at: in,
# Nearest to at: in, during,
# Nearest to at: in, during, when,
# Nearest to at: in, during, when, after,
# Nearest to at: in, during, when, after, monuc,
# Nearest to at: in, during, when, after, monuc, almos,
# Nearest to at: in, during, when, after, monuc, almos, employes,
# Nearest to at: in, during, when, after, monuc, almos, employes, miohippus,
# Nearest to be: have,
# Nearest to be: have, been,
# Nearest to be: have, been, were,
# Nearest to be: have, been, were, being,
# Nearest to be: have, been, were, being, was,
# Nearest to be: have, been, were, being, was, is,
# Nearest to be: have, been, were, being, was, is, malaca,
# Nearest to be: have, been, were, being, was, is, malaca, become,
# Nearest to six: four,
# Nearest to six: four, eight,
# Nearest to six: four, eight, seven,
# Nearest to six: four, eight, seven, nine,
# Nearest to six: four, eight, seven, nine, five,
# Nearest to six: four, eight, seven, nine, five, three,
# Nearest to six: four, eight, seven, nine, five, three, two,
# Nearest to six: four, eight, seven, nine, five, three, two, one,
# Nearest to use: mazi,
# Nearest to use: mazi, order,
# Nearest to use: mazi, order, terms,
# Nearest to use: mazi, order, terms, labeouf,
# Nearest to use: mazi, order, terms, labeouf, flagellants,
# Nearest to use: mazi, order, terms, labeouf, flagellants, foi,
# Nearest to use: mazi, order, terms, labeouf, flagellants, foi, khov,
# Nearest to use: mazi, order, terms, labeouf, flagellants, foi, khov, mythen,
# Nearest to i: ii,
# Nearest to i: ii, unsandalled,
# Nearest to i: ii, unsandalled, you,
# Nearest to i: ii, unsandalled, you, johanssen,
# Nearest to i: ii, unsandalled, you, johanssen, we,
# Nearest to i: ii, unsandalled, you, johanssen, we, greenall,
# Nearest to i: ii, unsandalled, you, johanssen, we, greenall, asteropeiaceae,
# Nearest to i: ii, unsandalled, you, johanssen, we, greenall, asteropeiaceae, fenian,
# Nearest to on: upon,
# Nearest to on: upon, through,
# Nearest to on: upon, through, in,
# Nearest to on: upon, through, in, fxp,
# Nearest to on: upon, through, in, fxp, spinach,
# Nearest to on: upon, through, in, fxp, spinach, morta,
# Nearest to on: upon, through, in, fxp, spinach, morta, guiscard,
# Nearest to on: upon, through, in, fxp, spinach, morta, guiscard, erets,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, were,
# Nearest to had: has, have, was, were, having,
# Nearest to had: has, have, was, were, having, is,
# Nearest to had: has, have, was, were, having, is, yazidism,
# Nearest to had: has, have, was, were, having, is, yazidism, lugdunum,
# Nearest to after: when,
# Nearest to after: when, during,
# Nearest to after: when, during, before,
# Nearest to after: when, during, before, mananger,
# Nearest to after: when, during, before, mananger, at,
# Nearest to after: when, during, before, mananger, at, from,
# Nearest to after: when, during, before, mananger, at, from, was,
# Nearest to after: when, during, before, mananger, at, from, was, hayden,
# Nearest to may: can,
# Nearest to may: can, would,
# Nearest to may: can, would, must,
# Nearest to may: can, would, must, could,
# Nearest to may: can, would, must, could, will,
# Nearest to may: can, would, must, could, will, should,
# Nearest to may: can, would, must, could, will, should, might,
# Nearest to may: can, would, must, could, will, should, might, cannot,
# Nearest to were: are,
# Nearest to were: are, was,
# Nearest to were: are, was, had,
# Nearest to were: are, was, had, have,
# Nearest to were: are, was, had, have, been,
# Nearest to were: are, was, had, have, been, by,
# Nearest to were: are, was, had, have, been, by, be,
# Nearest to were: are, was, had, have, been, by, be, being,
# Nearest to however: but,
# Nearest to however: but, somnambulists,
# Nearest to however: but, somnambulists, that,
# Nearest to however: but, somnambulists, that, would,
# Nearest to however: but, somnambulists, that, would, though,
# Nearest to however: but, somnambulists, that, would, though, where,
# Nearest to however: but, somnambulists, that, would, though, where, while,
# Nearest to however: but, somnambulists, that, would, though, where, while, diplomarbeit,
# Nearest to when: if,
# Nearest to when: if, where,
# Nearest to when: if, where, after,
# Nearest to when: if, where, after, before,
# Nearest to when: if, where, after, before, for,
# Nearest to when: if, where, after, before, for, was,
# Nearest to when: if, where, after, before, for, was, during,
# Nearest to when: if, where, after, before, for, was, during, within,
# Nearest to four: six,
# Nearest to four: six, five,
# Nearest to four: six, five, three,
# Nearest to four: six, five, three, eight,
# Nearest to four: six, five, three, eight, seven,
# Nearest to four: six, five, three, eight, seven, two,
# Nearest to four: six, five, three, eight, seven, two, nine,
# Nearest to four: six, five, three, eight, seven, two, nine, one,
# Nearest to history: segregating,
# Nearest to history: segregating, church,
# Nearest to history: segregating, church, house,
# Nearest to history: segregating, church, house, grammatica,
# Nearest to history: segregating, church, house, grammatica, gambas,
# Nearest to history: segregating, church, house, grammatica, gambas, science,
# Nearest to history: segregating, church, house, grammatica, gambas, science, gottwald,
# Nearest to history: segregating, church, house, grammatica, gambas, science, gottwald, literary,
# Average loss at step 32000: 3.537204
# Average loss at step 34000: 3.520430
# Average loss at step 36000: 3.486125
# Average loss at step 38000: 3.313006
# Average loss at step 40000: 3.454881
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, longer,
# Nearest to more: less, most, very, longer, sawamatsu,
# Nearest to more: less, most, very, longer, sawamatsu, vilchis,
# Nearest to more: less, most, very, longer, sawamatsu, vilchis, really,
# Nearest to more: less, most, very, longer, sawamatsu, vilchis, really, satirically,
# Nearest to in: of,
# Nearest to in: of, for,
# Nearest to in: of, for, within,
# Nearest to in: of, for, within, on,
# Nearest to in: of, for, within, on, throughout,
# Nearest to in: of, for, within, on, throughout, when,
# Nearest to in: of, for, within, on, throughout, when, from,
# Nearest to in: of, for, within, on, throughout, when, from, if,
# Nearest to at: during,
# Nearest to at: during, in,
# Nearest to at: during, in, after,
# Nearest to at: during, in, after, monuc,
# Nearest to at: during, in, after, monuc, on,
# Nearest to at: during, in, after, monuc, on, optimo,
# Nearest to at: during, in, after, monuc, on, optimo, against,
# Nearest to at: during, in, after, monuc, on, optimo, against, enchanted,
# Nearest to be: have,
# Nearest to be: have, been,
# Nearest to be: have, been, being,
# Nearest to be: have, been, being, was,
# Nearest to be: have, been, being, was, is,
# Nearest to be: have, been, being, was, is, were,
# Nearest to be: have, been, being, was, is, were, leberecht,
# Nearest to be: have, been, being, was, is, were, leberecht, become,
# Nearest to six: seven,
# Nearest to six: seven, four,
# Nearest to six: seven, four, eight,
# Nearest to six: seven, four, eight, five,
# Nearest to six: seven, four, eight, five, three,
# Nearest to six: seven, four, eight, five, three, nine,
# Nearest to six: seven, four, eight, five, three, nine, two,
# Nearest to six: seven, four, eight, five, three, nine, two, one,
# Nearest to use: terms,
# Nearest to use: terms, order,
# Nearest to use: terms, order, luigia,
# Nearest to use: terms, order, luigia, mythen,
# Nearest to use: terms, order, luigia, mythen, mazi,
# Nearest to use: terms, order, luigia, mythen, mazi, changes,
# Nearest to use: terms, order, luigia, mythen, mazi, changes, sciences,
# Nearest to use: terms, order, luigia, mythen, mazi, changes, sciences, bolingbroke,
# Nearest to i: ii,
# Nearest to i: ii, you,
# Nearest to i: ii, you, they,
# Nearest to i: ii, you, they, we,
# Nearest to i: ii, you, they, we, he,
# Nearest to i: ii, you, they, we, he, unsandalled,
# Nearest to i: ii, you, they, we, he, unsandalled, blear,
# Nearest to i: ii, you, they, we, he, unsandalled, blear, fenian,
# Nearest to on: upon,
# Nearest to on: upon, through,
# Nearest to on: upon, through, in,
# Nearest to on: upon, through, in, within,
# Nearest to on: upon, through, in, within, during,
# Nearest to on: upon, through, in, within, during, with,
# Nearest to on: upon, through, in, within, during, with, at,
# Nearest to on: upon, through, in, within, during, with, at, wiggler,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, were,
# Nearest to had: has, have, was, were, began,
# Nearest to had: has, have, was, were, began, having,
# Nearest to had: has, have, was, were, began, having, rebecque,
# Nearest to had: has, have, was, were, began, having, rebecque, lugdunum,
# Nearest to after: before,
# Nearest to after: before, during,
# Nearest to after: before, during, when,
# Nearest to after: before, during, when, cultiral,
# Nearest to after: before, during, when, cultiral, at,
# Nearest to after: before, during, when, cultiral, at, treatises,
# Nearest to after: before, during, when, cultiral, at, treatises, parijs,
# Nearest to after: before, during, when, cultiral, at, treatises, parijs, flotations,
# Nearest to may: can,
# Nearest to may: can, must,
# Nearest to may: can, must, will,
# Nearest to may: can, must, will, would,
# Nearest to may: can, must, will, would, could,
# Nearest to may: can, must, will, would, could, should,
# Nearest to may: can, must, will, would, could, should, might,
# Nearest to may: can, must, will, would, could, should, might, cannot,
# Nearest to were: are,
# Nearest to were: are, have,
# Nearest to were: are, have, was,
# Nearest to were: are, have, was, had,
# Nearest to were: are, have, was, had, being,
# Nearest to were: are, have, was, had, being, while,
# Nearest to were: are, have, was, had, being, while, been,
# Nearest to were: are, have, was, had, being, while, been, be,
# Nearest to however: but,
# Nearest to however: but, though,
# Nearest to however: but, though, they,
# Nearest to however: but, though, they, where,
# Nearest to however: but, though, they, where, that,
# Nearest to however: but, though, they, where, that, while,
# Nearest to however: but, though, they, where, that, while, although,
# Nearest to however: but, though, they, where, that, while, although, somnambulists,
# Nearest to when: if,
# Nearest to when: if, before,
# Nearest to when: if, before, where,
# Nearest to when: if, before, where, after,
# Nearest to when: if, before, where, after, while,
# Nearest to when: if, before, where, after, while, though,
# Nearest to when: if, before, where, after, while, though, during,
# Nearest to when: if, before, where, after, while, though, during, for,
# Nearest to four: six,
# Nearest to four: six, seven,
# Nearest to four: six, seven, three,
# Nearest to four: six, seven, three, five,
# Nearest to four: six, seven, three, five, eight,
# Nearest to four: six, seven, three, five, eight, two,
# Nearest to four: six, seven, three, five, eight, two, nine,
# Nearest to four: six, seven, three, five, eight, two, nine, one,
# Nearest to history: segregating,
# Nearest to history: segregating, grammatica,
# Nearest to history: segregating, grammatica, gottwald,
# Nearest to history: segregating, grammatica, gottwald, polyphenol,
# Nearest to history: segregating, grammatica, gottwald, polyphenol, velma,
# Nearest to history: segregating, grammatica, gottwald, polyphenol, velma, afl,
# Nearest to history: segregating, grammatica, gottwald, polyphenol, velma, afl, flexography,
# Nearest to history: segregating, grammatica, gottwald, polyphenol, velma, afl, flexography, gambas,
# Average loss at step 42000: 3.444607
# Average loss at step 44000: 3.463745
# Average loss at step 46000: 3.458730
# Average loss at step 48000: 3.356103
# Average loss at step 50000: 3.385775
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, illustrated,
# Nearest to more: less, most, very, illustrated, longer,
# Nearest to more: less, most, very, illustrated, longer, smaller,
# Nearest to more: less, most, very, illustrated, longer, smaller, rather,
# Nearest to more: less, most, very, illustrated, longer, smaller, rather, sawamatsu,
# Nearest to in: during,
# Nearest to in: during, from,
# Nearest to in: during, from, since,
# Nearest to in: during, from, since, of,
# Nearest to in: during, from, since, of, throughout,
# Nearest to in: during, from, since, of, throughout, chodzie,
# Nearest to in: during, from, since, of, throughout, chodzie, at,
# Nearest to in: during, from, since, of, throughout, chodzie, at, on,
# Nearest to at: in,
# Nearest to at: in, during,
# Nearest to at: in, during, dehydrated,
# Nearest to at: in, during, dehydrated, after,
# Nearest to at: in, during, dehydrated, after, near,
# Nearest to at: in, during, dehydrated, after, near, from,
# Nearest to at: in, during, dehydrated, after, near, from, cronulla,
# Nearest to at: in, during, dehydrated, after, near, from, cronulla, enchanted,
# Nearest to be: have,
# Nearest to be: have, being,
# Nearest to be: have, being, been,
# Nearest to be: have, being, been, become,
# Nearest to be: have, being, been, become, was,
# Nearest to be: have, being, been, become, was, produce,
# Nearest to be: have, being, been, become, was, produce, alarm,
# Nearest to be: have, being, been, become, was, produce, alarm, were,
# Nearest to six: eight,
# Nearest to six: eight, seven,
# Nearest to six: eight, seven, four,
# Nearest to six: eight, seven, four, nine,
# Nearest to six: eight, seven, four, nine, three,
# Nearest to six: eight, seven, four, nine, three, five,
# Nearest to six: eight, seven, four, nine, three, five, two,
# Nearest to six: eight, seven, four, nine, three, five, two, one,
# Nearest to use: terms,
# Nearest to use: terms, order,
# Nearest to use: terms, order, mythen,
# Nearest to use: terms, order, mythen, most,
# Nearest to use: terms, order, mythen, most, luigia,
# Nearest to use: terms, order, mythen, most, luigia, changes,
# Nearest to use: terms, order, mythen, most, luigia, changes, sciences,
# Nearest to use: terms, order, mythen, most, luigia, changes, sciences, gasparini,
# Nearest to i: ii,
# Nearest to i: ii, you,
# Nearest to i: ii, you, we,
# Nearest to i: ii, you, we, unsandalled,
# Nearest to i: ii, you, we, unsandalled, blear,
# Nearest to i: ii, you, we, unsandalled, blear, g,
# Nearest to i: ii, you, we, unsandalled, blear, g, kazurinsky,
# Nearest to i: ii, you, we, unsandalled, blear, g, kazurinsky, duraiappah,
# Nearest to on: upon,
# Nearest to on: upon, through,
# Nearest to on: upon, through, within,
# Nearest to on: upon, through, within, in,
# Nearest to on: upon, through, within, in, fxp,
# Nearest to on: upon, through, within, in, fxp, under,
# Nearest to on: upon, through, within, in, fxp, under, from,
# Nearest to on: upon, through, within, in, fxp, under, from, over,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, were,
# Nearest to had: has, have, was, were, having,
# Nearest to had: has, have, was, were, having, since,
# Nearest to had: has, have, was, were, having, since, been,
# Nearest to had: has, have, was, were, having, since, been, would,
# Nearest to after: before,
# Nearest to after: before, when,
# Nearest to after: before, when, during,
# Nearest to after: before, when, during, but,
# Nearest to after: before, when, during, but, while,
# Nearest to after: before, when, during, but, while, cultiral,
# Nearest to after: before, when, during, but, while, cultiral, from,
# Nearest to after: before, when, during, but, while, cultiral, from, if,
# Nearest to may: can,
# Nearest to may: can, must,
# Nearest to may: can, must, could,
# Nearest to may: can, must, could, would,
# Nearest to may: can, must, could, would, will,
# Nearest to may: can, must, could, would, will, should,
# Nearest to may: can, must, could, would, will, should, might,
# Nearest to may: can, must, could, would, will, should, might, cannot,
# Nearest to were: are,
# Nearest to were: are, was,
# Nearest to were: are, was, have,
# Nearest to were: are, was, have, had,
# Nearest to were: are, was, have, had, although,
# Nearest to were: are, was, have, had, although, is,
# Nearest to were: are, was, have, had, although, is, being,
# Nearest to were: are, was, have, had, although, is, being, covenas,
# Nearest to however: but,
# Nearest to however: but, although,
# Nearest to however: but, although, though,
# Nearest to however: but, although, though, that,
# Nearest to however: but, although, though, that, while,
# Nearest to however: but, although, though, that, while, where,
# Nearest to however: but, although, though, that, while, where, when,
# Nearest to however: but, although, though, that, while, where, when, since,
# Nearest to when: if,
# Nearest to when: if, after,
# Nearest to when: if, after, before,
# Nearest to when: if, after, before, while,
# Nearest to when: if, after, before, while, though,
# Nearest to when: if, after, before, while, though, but,
# Nearest to when: if, after, before, while, though, but, where,
# Nearest to when: if, after, before, while, though, but, where, during,
# Nearest to four: six,
# Nearest to four: six, five,
# Nearest to four: six, five, seven,
# Nearest to four: six, five, seven, three,
# Nearest to four: six, five, seven, three, eight,
# Nearest to four: six, five, seven, three, eight, nine,
# Nearest to four: six, five, seven, three, eight, nine, two,
# Nearest to four: six, five, seven, three, eight, nine, two, one,
# Nearest to history: velma,
# Nearest to history: velma, rafik,
# Nearest to history: velma, rafik, grammatica,
# Nearest to history: velma, rafik, grammatica, thermophiles,
# Nearest to history: velma, rafik, grammatica, thermophiles, list,
# Nearest to history: velma, rafik, grammatica, thermophiles, list, gottwald,
# Nearest to history: velma, rafik, grammatica, thermophiles, list, gottwald, comm,
# Nearest to history: velma, rafik, grammatica, thermophiles, list, gottwald, comm, aleppo,
# Average loss at step 52000: 3.445716
# Average loss at step 54000: 3.437121
# Average loss at step 56000: 3.438089
# Average loss at step 58000: 3.386765
# Average loss at step 60000: 3.378482
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, rather,
# Nearest to more: less, most, very, rather, longer,
# Nearest to more: less, most, very, rather, longer, smaller,
# Nearest to more: less, most, very, rather, longer, smaller, illustrated,
# Nearest to more: less, most, very, rather, longer, smaller, illustrated, sawamatsu,
# Nearest to in: within,
# Nearest to in: within, during,
# Nearest to in: within, during, throughout,
# Nearest to in: within, during, throughout, since,
# Nearest to in: within, during, throughout, since, at,
# Nearest to in: within, during, throughout, since, at, on,
# Nearest to in: within, during, throughout, since, at, on, of,
# Nearest to in: within, during, throughout, since, at, on, of, hurlant,
# Nearest to at: during,
# Nearest to at: during, in,
# Nearest to at: during, in, cronulla,
# Nearest to at: during, in, cronulla, asterius,
# Nearest to at: during, in, cronulla, asterius, almos,
# Nearest to at: during, in, cronulla, asterius, almos, after,
# Nearest to at: during, in, cronulla, asterius, almos, after, enchanted,
# Nearest to at: during, in, cronulla, asterius, almos, after, enchanted, grimacing,
# Nearest to be: been,
# Nearest to be: been, was,
# Nearest to be: been, was, is,
# Nearest to be: been, was, is, being,
# Nearest to be: been, was, is, being, have,
# Nearest to be: been, was, is, being, have, become,
# Nearest to be: been, was, is, being, have, become, are,
# Nearest to be: been, was, is, being, have, become, are, baggio,
# Nearest to six: eight,
# Nearest to six: eight, four,
# Nearest to six: eight, four, five,
# Nearest to six: eight, four, five, nine,
# Nearest to six: eight, four, five, nine, seven,
# Nearest to six: eight, four, five, nine, seven, three,
# Nearest to six: eight, four, five, nine, seven, three, two,
# Nearest to six: eight, four, five, nine, seven, three, two, zero,
# Nearest to use: terms,
# Nearest to use: terms, mythen,
# Nearest to use: terms, mythen, order,
# Nearest to use: terms, mythen, order, monocotyledonous,
# Nearest to use: terms, mythen, order, monocotyledonous, principle,
# Nearest to use: terms, mythen, order, monocotyledonous, principle, most,
# Nearest to use: terms, mythen, order, monocotyledonous, principle, most, stramonium,
# Nearest to use: terms, mythen, order, monocotyledonous, principle, most, stramonium, viegas,
# Nearest to i: ii,
# Nearest to i: ii, you,
# Nearest to i: ii, you, we,
# Nearest to i: ii, you, we, unsandalled,
# Nearest to i: ii, you, we, unsandalled, asteropeiaceae,
# Nearest to i: ii, you, we, unsandalled, asteropeiaceae, g,
# Nearest to i: ii, you, we, unsandalled, asteropeiaceae, g, duraiappah,
# Nearest to i: ii, you, we, unsandalled, asteropeiaceae, g, duraiappah, t,
# Nearest to on: upon,
# Nearest to on: upon, through,
# Nearest to on: upon, through, within,
# Nearest to on: upon, through, within, in,
# Nearest to on: upon, through, within, in, under,
# Nearest to on: upon, through, within, in, under, wiggler,
# Nearest to on: upon, through, within, in, under, wiggler, with,
# Nearest to on: upon, through, within, in, under, wiggler, with, kmen,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, were,
# Nearest to had: has, have, was, were, having,
# Nearest to had: has, have, was, were, having, rogge,
# Nearest to had: has, have, was, were, having, rogge, beheld,
# Nearest to had: has, have, was, were, having, rogge, beheld, wheeled,
# Nearest to after: before,
# Nearest to after: before, during,
# Nearest to after: before, during, when,
# Nearest to after: before, during, when, while,
# Nearest to after: before, during, when, while, since,
# Nearest to after: before, during, when, while, since, if,
# Nearest to after: before, during, when, while, since, if, antipersonnel,
# Nearest to after: before, during, when, while, since, if, antipersonnel, despite,
# Nearest to may: can,
# Nearest to may: can, must,
# Nearest to may: can, must, would,
# Nearest to may: can, must, would, could,
# Nearest to may: can, must, would, could, will,
# Nearest to may: can, must, would, could, will, might,
# Nearest to may: can, must, would, could, will, might, should,
# Nearest to may: can, must, would, could, will, might, should, cannot,
# Nearest to were: are,
# Nearest to were: are, have,
# Nearest to were: are, have, was,
# Nearest to were: are, have, was, had,
# Nearest to were: are, have, was, had, although,
# Nearest to were: are, have, was, had, although, including,
# Nearest to were: are, have, was, had, although, including, while,
# Nearest to were: are, have, was, had, although, including, while, but,
# Nearest to however: but,
# Nearest to however: but, although,
# Nearest to however: but, although, though,
# Nearest to however: but, although, though, since,
# Nearest to however: but, although, though, since, that,
# Nearest to however: but, although, though, since, that, which,
# Nearest to however: but, although, though, since, that, which, and,
# Nearest to however: but, although, though, since, that, which, and, while,
# Nearest to when: if,
# Nearest to when: if, before,
# Nearest to when: if, before, after,
# Nearest to when: if, before, after, although,
# Nearest to when: if, before, after, although, during,
# Nearest to when: if, before, after, although, during, though,
# Nearest to when: if, before, after, although, during, though, while,
# Nearest to when: if, before, after, although, during, though, while, where,
# Nearest to four: five,
# Nearest to four: five, six,
# Nearest to four: five, six, three,
# Nearest to four: five, six, three, eight,
# Nearest to four: five, six, three, eight, seven,
# Nearest to four: five, six, three, eight, seven, two,
# Nearest to four: five, six, three, eight, seven, two, nine,
# Nearest to four: five, six, three, eight, seven, two, nine, one,
# Nearest to history: flexography,
# Nearest to history: flexography, thermophiles,
# Nearest to history: flexography, thermophiles, rafik,
# Nearest to history: flexography, thermophiles, rafik, aleppo,
# Nearest to history: flexography, thermophiles, rafik, aleppo, amamians,
# Nearest to history: flexography, thermophiles, rafik, aleppo, amamians, science,
# Nearest to history: flexography, thermophiles, rafik, aleppo, amamians, science, grammatica,
# Nearest to history: flexography, thermophiles, rafik, aleppo, amamians, science, grammatica, literary,
# Average loss at step 62000: 3.227372
# Average loss at step 64000: 3.245796
# Average loss at step 66000: 3.394966
# Average loss at step 68000: 3.393587
# Average loss at step 70000: 3.343577
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, longer,
# Nearest to more: less, most, very, longer, rather,
# Nearest to more: less, most, very, longer, rather, illustrated,
# Nearest to more: less, most, very, longer, rather, illustrated, sawamatsu,
# Nearest to more: less, most, very, longer, rather, illustrated, sawamatsu, quite,
# Nearest to in: during,
# Nearest to in: during, within,
# Nearest to in: during, within, on,
# Nearest to in: during, within, on, throughout,
# Nearest to in: during, within, on, throughout, methanoate,
# Nearest to in: during, within, on, throughout, methanoate, for,
# Nearest to in: during, within, on, throughout, methanoate, for, until,
# Nearest to in: during, within, on, throughout, methanoate, for, until, since,
# Nearest to at: during,
# Nearest to at: during, cronulla,
# Nearest to at: during, cronulla, asterius,
# Nearest to at: during, cronulla, asterius, after,
# Nearest to at: during, cronulla, asterius, after, in,
# Nearest to at: during, cronulla, asterius, after, in, near,
# Nearest to at: during, cronulla, asterius, after, in, near, paradoxically,
# Nearest to at: during, cronulla, asterius, after, in, near, paradoxically, including,
# ...
# Nearest to i: we, ii, you, g, kazurinsky, pedagogical, t, iii,
# Nearest to on: upon,
# Nearest to on: upon, in,
# Nearest to on: upon, in, through,
# Nearest to on: upon, in, through, during,
# Nearest to on: upon, in, through, during, within,
# Nearest to on: upon, in, through, during, within, under,
# Nearest to on: upon, in, through, during, within, under, including,
# Nearest to on: upon, in, through, during, within, under, including, at,
# Nearest to had: have,
# Nearest to had: have, has,
# Nearest to had: have, has, was,
# Nearest to had: have, has, was, were,
# Nearest to had: have, has, was, were, having,
# Nearest to had: have, has, was, were, having, wheeled,
# Nearest to had: have, has, was, were, having, wheeled, began,
# Nearest to had: have, has, was, were, having, wheeled, began, saw,
# Nearest to after: before,
# Nearest to after: before, during,
# Nearest to after: before, during, when,
# Nearest to after: before, during, when, while,
# Nearest to after: before, during, when, while, though,
# Nearest to after: before, during, when, while, though, upon,
# Nearest to after: before, during, when, while, though, upon, from,
# Nearest to after: before, during, when, while, though, upon, from, if,
# Nearest to may: could,
# Nearest to may: could, can,
# Nearest to may: could, can, must,
# Nearest to may: could, can, must, would,
# Nearest to may: could, can, must, would, might,
# Nearest to may: could, can, must, would, might, will,
# Nearest to may: could, can, must, would, might, will, should,
# Nearest to may: could, can, must, would, might, will, should, cannot,
# Nearest to were: are,
# Nearest to were: are, had,
# Nearest to were: are, had, have,
# Nearest to were: are, had, have, was,
# Nearest to were: are, had, have, was, being,
# Nearest to were: are, had, have, was, being, although,
# Nearest to were: are, had, have, was, being, although, include,
# Nearest to were: are, had, have, was, being, although, include, those,
# Nearest to however: but,
# Nearest to however: but, although,
# Nearest to however: but, although, though,
# Nearest to however: but, although, though, that,
# Nearest to however: but, although, though, that, while,
# Nearest to however: but, although, though, that, while, where,
# Nearest to however: but, although, though, that, while, where, since,
# Nearest to however: but, although, though, that, while, where, since, when,
# Nearest to when: before,
# Nearest to when: before, if,
# Nearest to when: before, if, though,
# Nearest to when: before, if, though, after,
# Nearest to when: before, if, though, after, during,
# Nearest to when: before, if, though, after, during, where,
# Nearest to when: before, if, though, after, during, where, while,
# Nearest to when: before, if, though, after, during, where, while, although,
# Nearest to four: six,
# Nearest to four: six, five,
# Nearest to four: six, five, seven,
# Nearest to four: six, five, seven, three,
# Nearest to four: six, five, seven, three, eight,
# Nearest to four: six, five, seven, three, eight, two,
# Nearest to four: six, five, seven, three, eight, two, nine,
# Nearest to four: six, five, seven, three, eight, two, nine, one,
# Nearest to history: introduction,
# Nearest to history: introduction, list,
# Nearest to history: introduction, list, flexography,
# Nearest to history: introduction, list, flexography, thermophiles,
# Nearest to history: introduction, list, flexography, thermophiles, velma,
# Nearest to history: introduction, list, flexography, thermophiles, velma, trichoptera,
# Nearest to history: introduction, list, flexography, thermophiles, velma, trichoptera, supersite,
# Nearest to history: introduction, list, flexography, thermophiles, velma, trichoptera, supersite, amamians,
# Average loss at step 82000: 3.394800
# Average loss at step 84000: 3.401142
# Average loss at step 86000: 3.383178
# Average loss at step 88000: 3.317580
# Average loss at step 90000: 3.352639
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, longer,
# Nearest to more: less, most, very, longer, quite,
# Nearest to more: less, most, very, longer, quite, rather,
# Nearest to more: less, most, very, longer, quite, rather, better,
# Nearest to more: less, most, very, longer, quite, rather, better, illustrated,
# Nearest to in: during,
# Nearest to in: during, within,
# Nearest to in: during, within, with,
# Nearest to in: during, within, with, until,
# Nearest to in: during, within, with, until, around,
# Nearest to in: during, within, with, until, around, at,
# Nearest to in: during, within, with, until, around, at, between,
# Nearest to in: during, within, with, until, around, at, between, under,
# Nearest to at: near,
# Nearest to at: near, during,
# Nearest to at: near, during, in,
# Nearest to at: near, during, in, muralists,
# Nearest to at: near, during, in, muralists, on,
# Nearest to at: near, during, in, muralists, on, after,
# Nearest to at: near, during, in, muralists, on, after, ekman,
# Nearest to at: near, during, in, muralists, on, after, ekman, almos,
# Nearest to be: been,
# Nearest to be: been, have,
# Nearest to be: been, have, being,
# Nearest to be: been, have, being, become,
# Nearest to be: been, have, being, become, is,
# Nearest to be: been, have, being, become, is, produce,
# Nearest to be: been, have, being, become, is, produce, refer,
# Nearest to be: been, have, being, become, is, produce, refer, tcat,
# Nearest to six: eight,
# Nearest to six: eight, seven,
# Nearest to six: eight, seven, four,
# Nearest to six: eight, seven, four, five,
# Nearest to six: eight, seven, four, five, nine,
# Nearest to six: eight, seven, four, five, nine, three,
# Nearest to six: eight, seven, four, five, nine, three, two,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to use: terms,
# Nearest to use: terms, because,
# Nearest to use: terms, because, cause,
# Nearest to use: terms, because, cause, mythen,
# Nearest to use: terms, because, cause, mythen, help,
# Nearest to use: terms, because, cause, mythen, help, luigia,
# Nearest to use: terms, because, cause, mythen, help, luigia, principle,
# Nearest to use: terms, because, cause, mythen, help, luigia, principle, colourless,
# Nearest to i: we,
# Nearest to i: we, you,
# Nearest to i: we, you, ii,
# Nearest to i: we, you, ii, g,
# Nearest to i: we, you, ii, g, t,
# Nearest to i: we, you, ii, g, t, tavistock,
# Nearest to i: we, you, ii, g, t, tavistock, iv,
# Nearest to i: we, you, ii, g, t, tavistock, iv, iii,
# Nearest to on: upon,
# Nearest to on: upon, under,
# Nearest to on: upon, under, through,
# Nearest to on: upon, under, through, in,
# Nearest to on: upon, under, through, in, at,
# Nearest to on: upon, under, through, in, at, kone,
# Nearest to on: upon, under, through, in, at, kone, cth,
# Nearest to on: upon, under, through, in, at, kone, cth, plagioclimax,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, were,
# Nearest to had: has, have, was, were, having,
# Nearest to had: has, have, was, were, having, orthonormal,
# Nearest to had: has, have, was, were, having, orthonormal, began,
# Nearest to had: has, have, was, were, having, orthonormal, began, backstreet,
# Nearest to after: before,
# Nearest to after: before, during,
# Nearest to after: before, during, when,
# Nearest to after: before, during, when, while,
# Nearest to after: before, during, when, while, if,
# Nearest to after: before, during, when, while, if, upon,
# Nearest to after: before, during, when, while, if, upon, despite,
# Nearest to after: before, during, when, while, if, upon, despite, at,
# Nearest to may: can,
# Nearest to may: can, must,
# Nearest to may: can, must, could,
# Nearest to may: can, must, could, would,
# Nearest to may: can, must, could, would, might,
# Nearest to may: can, must, could, would, might, should,
# Nearest to may: can, must, could, would, might, should, will,
# Nearest to may: can, must, could, would, might, should, will, cannot,
# Nearest to were: are,
# Nearest to were: are, was,
# Nearest to were: are, was, had,
# Nearest to were: are, was, had, have,
# Nearest to were: are, was, had, have, although,
# Nearest to were: are, was, had, have, although, while,
# Nearest to were: are, was, had, have, although, while, covenas,
# Nearest to were: are, was, had, have, although, while, covenas, being,
# Nearest to however: but,
# Nearest to however: but, although,
# Nearest to however: but, although, though,
# Nearest to however: but, although, though, that,
# Nearest to however: but, although, though, that, while,
# Nearest to however: but, although, though, that, while, since,
# Nearest to however: but, although, though, that, while, since, if,
# Nearest to however: but, although, though, that, while, since, if, when,
# Nearest to when: before,
# Nearest to when: before, if,
# Nearest to when: before, if, while,
# Nearest to when: before, if, while, though,
# Nearest to when: before, if, while, though, after,
# Nearest to when: before, if, while, though, after, during,
# Nearest to when: before, if, while, though, after, during, where,
# Nearest to when: before, if, while, though, after, during, where, although,
# Nearest to four: seven,
# Nearest to four: seven, five,
# Nearest to four: seven, five, six,
# Nearest to four: seven, five, six, three,
# Nearest to four: seven, five, six, three, eight,
# Nearest to four: seven, five, six, three, eight, nine,
# Nearest to four: seven, five, six, three, eight, nine, two,
# Nearest to four: seven, five, six, three, eight, nine, two, one,
# Nearest to history: list,
# Nearest to history: list, supersite,
# Nearest to history: list, supersite, nicholl,
# Nearest to history: list, supersite, nicholl, velma,
# Nearest to history: list, supersite, nicholl, velma, flexography,
# Nearest to history: list, supersite, nicholl, velma, flexography, vendor,
# Nearest to history: list, supersite, nicholl, velma, flexography, vendor, sources,
# Nearest to history: list, supersite, nicholl, velma, flexography, vendor, sources, asymmetric,
# Average loss at step 92000: 3.379678
# Average loss at step 94000: 3.226256
# Average loss at step 96000: 3.345203
# Average loss at step 98000: 3.230248
# Average loss at step 100000: 3.339541
# Nearest to more: less,
# Nearest to more: less, most,
# Nearest to more: less, most, very,
# Nearest to more: less, most, very, quite,
# Nearest to more: less, most, very, quite, better,
# Nearest to more: less, most, very, quite, better, longer,
# Nearest to more: less, most, very, quite, better, longer, larger,
# Nearest to more: less, most, very, quite, better, longer, larger, rather,
# Nearest to in: within,
# Nearest to in: within, during,
# Nearest to in: within, during, on,
# Nearest to in: within, during, on, until,
# Nearest to in: within, during, on, until, from,
# Nearest to in: within, during, on, until, from, backstops,
# Nearest to in: within, during, on, until, from, backstops, through,
# Nearest to in: within, during, on, until, from, backstops, through, ekman,
# Nearest to at: near,
# Nearest to at: near, during,
# Nearest to at: near, during, on,
# Nearest to at: near, during, on, in,
# Nearest to at: near, during, on, in, after,
# Nearest to at: near, during, on, in, after, muralists,
# Nearest to at: near, during, on, in, after, muralists, dehydrated,
# Nearest to at: near, during, on, in, after, muralists, dehydrated, fulci,
# Nearest to be: been,
# Nearest to be: been, being,
# Nearest to be: been, being, have,
# Nearest to be: been, being, have, become,
# Nearest to be: been, being, have, become, is,
# Nearest to be: been, being, have, become, is, convert,
# Nearest to be: been, being, have, become, is, convert, appealed,
# Nearest to be: been, being, have, become, is, convert, appealed, refer,
# Nearest to six: seven,
# Nearest to six: seven, four,
# Nearest to six: seven, four, eight,
# Nearest to six: seven, four, eight, five,
# Nearest to six: seven, four, eight, five, nine,
# Nearest to six: seven, four, eight, five, nine, three,
# Nearest to six: seven, four, eight, five, nine, three, two,
# Nearest to six: seven, four, eight, five, nine, three, two, zero,
# Nearest to use: terms,
# Nearest to use: terms, help,
# Nearest to use: terms, help, form,
# Nearest to use: terms, help, form, support,
# Nearest to use: terms, help, form, support, mythen,
# Nearest to use: terms, help, form, support, mythen, cause,
# Nearest to use: terms, help, form, support, mythen, cause, luigia,
# Nearest to use: terms, help, form, support, mythen, cause, luigia, reject,
# Nearest to i: we,
# Nearest to i: we, you,
# Nearest to i: we, you, ii,
# Nearest to i: we, you, ii, they,
# Nearest to i: we, you, ii, they, t,
# Nearest to i: we, you, ii, they, t, blear,
# Nearest to i: we, you, ii, they, t, blear, unsandalled,
# Nearest to i: we, you, ii, they, t, blear, unsandalled, g,
# Nearest to on: upon,
# Nearest to on: upon, in,
# Nearest to on: upon, in, through,
# Nearest to on: upon, in, through, at,
# Nearest to on: upon, in, through, at, within,
# Nearest to on: upon, in, through, at, within, under,
# Nearest to on: upon, in, through, at, within, under, cth,
# Nearest to on: upon, in, through, at, within, under, cth, near,
# Nearest to had: has,
# Nearest to had: has, have,
# Nearest to had: has, have, was,
# Nearest to had: has, have, was, having,
# Nearest to had: has, have, was, having, would,
# Nearest to had: has, have, was, having, would, orthonormal,
# Nearest to had: has, have, was, having, would, orthonormal, is,
# Nearest to had: has, have, was, having, would, orthonormal, is, were,
# Nearest to after: before,
# Nearest to after: before, during,
# Nearest to after: before, during, when,
# Nearest to after: before, during, when, while,
# Nearest to after: before, during, when, while, despite,
# Nearest to after: before, during, when, while, despite, without,
# Nearest to after: before, during, when, while, despite, without, since,
# Nearest to after: before, during, when, while, despite, without, since, upon,
# Nearest to may: can,
# Nearest to may: can, could,
# Nearest to may: can, could, should,
# Nearest to may: can, could, should, would,
# Nearest to may: can, could, should, would, must,
# Nearest to may: can, could, should, would, must, might,
# Nearest to may: can, could, should, would, must, might, will,
# Nearest to may: can, could, should, would, must, might, will, cannot,
# Nearest to were: are,
# Nearest to were: are, was,
# Nearest to were: are, was, have,
# Nearest to were: are, was, have, include,
# Nearest to were: are, was, have, include, although,
# Nearest to were: are, was, have, include, although, those,
# Nearest to were: are, was, have, include, although, those, these,
# Nearest to were: are, was, have, include, although, those, these, covenas,
# Nearest to however: but,
# Nearest to however: but, although,
# Nearest to however: but, although, that,
# Nearest to however: but, although, that, though,
# Nearest to however: but, although, that, though, while,
# Nearest to however: but, although, that, though, while, where,
# Nearest to however: but, although, that, though, while, where, which,
# Nearest to however: but, although, that, though, while, where, which, and,
# Nearest to when: if,
# Nearest to when: if, while,
# Nearest to when: if, while, before,
# Nearest to when: if, while, before, though,
# Nearest to when: if, while, before, though, where,
# Nearest to when: if, while, before, though, where, after,
# Nearest to when: if, while, before, though, where, after, although,
# Nearest to when: if, while, before, though, where, after, although, during,
# Nearest to four: seven,
# Nearest to four: seven, six,
# Nearest to four: seven, six, five,
# Nearest to four: seven, six, five, eight,
# Nearest to four: seven, six, five, eight, two,
# Nearest to four: seven, six, five, eight, two, three,
# Nearest to four: seven, six, five, eight, two, three, nine,
# Nearest to four: seven, six, five, eight, two, three, nine, zero,
# Nearest to history: list,
# Nearest to history: list, science,
# Nearest to history: list, science, nicholl,
# Nearest to history: list, science, nicholl, introduction,
# Nearest to history: list, science, nicholl, introduction, drama,
# Nearest to history: list, science, nicholl, introduction, drama, griots,
# Nearest to history: list, science, nicholl, introduction, drama, griots, warehoused,
# Nearest to history: list, science, nicholl, introduction, drama, griots, warehoused, understanding,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %%
'''
An alternative to skip-gram is another Word2Vec model called CBOW (Continuous Bag of Words). 
In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the 
sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
'''
# Function to generate a training batch for the skip-gram model.
data_index = 0
def generate_cbowbatch(batch_size, skip_window):
    # skips_window: int : How many words to consider left and right.
    global data_index
    batch = np.ndarray(shape=(batch_size, skip_window*2), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size,1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    
    for i in range(batch_size):
        batch[i] = list(buffer)[:skip_window] + list(buffer)[skip_window+1:]
        labels[i] = buffer[skip_window]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    return batch, labels

# %%
# CBOW model

batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
"""
We pick a random validation set to sample nearest neighbors. here we limit the
validation samples to the words that have a low numeric ID, which by
construction are also the most frequent. 
"""
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    # Input data.
    # note the different input dimensions for the CBOW model
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,skip_window*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size],
                                                      stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    # note the sum over the context embeddings for the CBOW model
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    embed = tf.reduce_sum(embed, 1)

    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                                     train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_cbowbatch(batch_size, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-17-f99f4ae27f77>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.918325
# Nearest to for: bugguide, sate, dulo, condiment, immobilising, leyenda, xiamen, dks,
# Nearest to only: raiway, damoiselle, honourable, lcy, contabile, ruficaudus, coblers, ejaculation,
# Nearest to but: loor, shrubbery, necropsittacus, unsmoothed, articling, tamazight, gira, benozzo,
# Nearest to state: micas, scheffler, arminianist, bleakness, fokonolona, skeleton, guattari, mixture,
# Nearest to of: excelle, amidships, unrated, risi, kreyentes, scandinavias, hashkivenu, evangelion,
# Nearest to in: broadsheet, muay, melezitose, kefauver, uncommunicative, obhrai, redroot, microchips,
# Nearest to up: nutting, unfilled, landaise, arahats, matisation, nborg, chiburdanidze, uld,
# Nearest to been: rousse, fairs, ickx, objectada, dargestellt, dunbar, herschell, francesco,
# Nearest to also: intelligibility, mainers, seafish, clubes, tressure, romsdal, brahmachaaryaashram, propelling,
# Nearest to one: porkpie, lexicographer, whiche, analogical, mergetek, darga, milligan, restamped,
# Nearest to no: thujone, audition, cangjie, hondo, unapologetically, botvinnik, enscounce, stringing,
# Nearest to with: helmich, sausages, miltia, ludendorff, kipling, mplm, sunna, sniffin,
# Nearest to is: agriculturalist, horsley, berecynthian, dword, bails, eadgyth, beatlelinks, mura,
# Nearest to people: superordo, pffft, dreaminess, urbock, consolidate, ashmedai, weidmann, artedi,
# Nearest to used: ricercari, cornellian, aicn, mustering, puzzlingly, jeanie, aldegisel, alfrik,
# Nearest to to: mandarin, caned, perioikoi, gujrati, santarem, fleurieu, mumble, tuqay,
# Average loss at step 2000: 4.526219
# Average loss at step 4000: 3.781560
# Average loss at step 6000: 3.568270
# Average loss at step 8000: 3.398851
# Average loss at step 10000: 3.290793
# Nearest to for: merarites, with, ighli, tzimtzum, truely, bivouacked, rohde, timi,
# Nearest to only: potrayed, gabrielli, drafted, subheading, holwg, damoiselle, macclesfield, atonement,
# Nearest to but: if, jeepguide, which, railhead, sariel, briolette, loriot, will,
# Nearest to state: phamaceutical, micas, capsid, umbrian, mundi, strengthening, libertarian, rigzone,
# Nearest to of: in, gramenet, repose, frontierlandia, shakuntala, ancrumia, curios, excelle,
# Nearest to in: at, on, under, of, during, with, centromere, from,
# Nearest to up: nutting, nborg, matisation, unfilled, ultrix, certainty, illes, mcb,
# Nearest to been: become, watcher, thermosphere, megaparsecs, ginian, were, sokolnikov, pittheus,
# Nearest to also: never, correlated, often, which, now, beefed, colombo, not,
# Nearest to one: eight, three, choruses, two, six, four, zamani, cursed,
# Nearest to no: bolides, ammonihah, upholders, twitty, a, audition, teleprinters, enscounce,
# Nearest to with: between, sausages, for, in, fleece, halaesus, millsaps, rubella,
# Nearest to is: was, has, are, does, praha, sexuality, dholaki, deciphering,
# Nearest to people: eildon, mashlim, viktor, oinaion, intermediary, weidmann, undignified, women,
# Nearest to used: cornellian, found, defined, prolog, starship, skynner, famnode, known,
# Nearest to to: around, would, could, radicalisation, perioikoi, can, dhanraj, chipminck,
# Average loss at step 12000: 3.297050
# Average loss at step 14000: 3.244394
# Average loss at step 16000: 3.262312
# Average loss at step 18000: 3.189032
# Average loss at step 20000: 3.046061
# Nearest to for: bivouacked, dks, starters, rhine, elisabeth, when, truely, in,
# Nearest to only: drafted, brushing, potrayed, damoiselle, cycling, taegunju, inspite, macclesfield,
# Nearest to but: however, and, while, although, which, brightness, though, rudram,
# Nearest to state: capsid, manlike, city, rigzone, loops, rerun, taizhou, micas,
# Nearest to of: immunizations, levick, groupie, roemischer, bowmen, in, for, deliberating,
# Nearest to in: during, at, within, ciampi, coupon, coachbuilders, on, carmell,
# Nearest to up: him, off, nutting, nborg, them, out, ultrix, sikosek,
# Nearest to been: become, be, already, ginian, was, watcher, megaparsecs, are,
# Nearest to also: which, often, sometimes, now, still, never, actually, mellower,
# Nearest to one: two, gadgetinis, kiyooka, five, tarictic, harnessable, sybaris, benzodiazepines,
# Nearest to no: any, trample, ammonihah, whitetip, teleprinters, bolides, upholders, a,
# Nearest to with: between, suchet, urate, loophole, milwaukeeans, millsaps, sniffin, droed,
# Nearest to is: was, has, are, became, be, does, crispness, dword,
# Nearest to people: eildon, men, women, shittr, udi, viktor, salves, species,
# Nearest to used: known, defined, found, cornellian, anew, famnode, pointing, considered,
# Nearest to to: perioikoi, flagg, would, colme, chipminck, peltatum, paradies, must,
# Average loss at step 22000: 3.119503
# Average loss at step 24000: 3.076958
# Average loss at step 26000: 3.047831
# Average loss at step 28000: 3.067906
# Average loss at step 30000: 3.032248
# Nearest to for: zukuri, nowrap, vidriera, tzimtzum, antigua, cartwright, rhine, bivouacked,
# Nearest to only: drafted, mallas, inspite, landoumas, alexiad, sheperd, obcordatus, denby,
# Nearest to but: however, and, although, include, tsui, until, though, brightness,
# Nearest to state: rerun, states, city, capsid, manlike, loops, mundi, danquah,
# Nearest to of: in, veslefrikk, simplificate, keyesville, including, varicose, dauthendey, shakuntala,
# Nearest to in: within, during, since, at, under, of, stadtbahn, sandyford,
# Nearest to up: off, them, out, him, nutting, sikosek, ultrix, devos,
# Nearest to been: become, be, was, already, ginian, were, matron, successfully,
# Nearest to also: still, often, now, sometimes, which, actually, never, typically,
# Nearest to one: two, five, choruses, six, issiac, three, uniformization, crossdos,
# Nearest to no: any, jutting, discoweb, whitetip, trample, skinner, cellphone, swabbing,
# Nearest to with: between, loophole, sausages, swadeshi, millsaps, milwaukeeans, sniffin, droed,
# Nearest to is: was, has, are, became, does, modulor, remains, although,
# Nearest to people: men, eildon, women, months, mohammedans, years, udi, countries,
# Nearest to used: known, defined, designed, accepted, anew, held, available, considered,
# Nearest to to: will, would, may, could, can, shortley, schweizerische, perioikoi,
# Average loss at step 32000: 2.847135
# Average loss at step 34000: 2.985398
# Average loss at step 36000: 2.971729
# Average loss at step 38000: 2.967469
# Average loss at step 40000: 2.982181
# Nearest to for: bivouacked, kleck, while, folkalley, substantia, of, including, hidaka,
# Nearest to only: chorded, holwg, svcd, drafted, azati, first, sauvage, sissons,
# Nearest to but: however, although, and, while, until, than, or, which,
# Nearest to state: states, city, umbrian, remake, phamaceutical, arduous, rerun, institute,
# Nearest to of: shakuntala, including, for, ancrumia, levick, from, smwtms, drylts,
# Nearest to in: during, within, throughout, abujmaria, stadtbahn, among, from, kirkjub,
# Nearest to up: off, out, him, them, nutting, sikosek, nborg, back,
# Nearest to been: become, be, were, already, ginian, polycleitus, previously, matron,
# Nearest to also: often, still, sometimes, now, never, which, usually, actually,
# Nearest to one: riegert, six, seven, gestes, swf, gadgetinis, refrains, eight,
# Nearest to no: any, soberan, approximatlly, dimerisation, discoweb, fro, stepchildren, little,
# Nearest to with: between, suchet, loophole, in, by, droed, sigilized, when,
# Nearest to is: was, has, becomes, are, seems, became, makes, being,
# Nearest to people: men, eildon, women, philosophers, countries, mohammedans, cases, groups,
# Nearest to used: defined, known, found, accepted, available, designed, written, given,
# Nearest to to: will, would, can, perioikoi, may, should, castillon, could,
# Average loss at step 42000: 2.973300
# Average loss at step 44000: 2.991635
# Average loss at step 46000: 2.919186
# Average loss at step 48000: 2.876118
# Average loss at step 50000: 2.872195
# Nearest to for: bivouacked, when, including, after, hidaka, kleck, against, zukuri,
# Nearest to only: lapadula, drafted, actually, either, even, not, helianthus, still,
# Nearest to but: although, however, while, though, and, contain, macatus, or,
# Nearest to state: states, branch, rerun, rigzone, city, loops, remake, multimeric,
# Nearest to of: in, during, including, kagaba, veslefrikk, wylde, wkdu, bowmen,
# Nearest to in: within, during, at, until, throughout, from, of, on,
# Nearest to up: off, out, him, back, them, sikosek, down, nutting,
# Nearest to been: become, be, already, previously, ginian, were, polycleitus, grandchildren,
# Nearest to also: still, often, now, usually, sometimes, actually, never, which,
# Nearest to one: two, seven, canada, moutiers, four, gadgetinis, grimnismol, gestes,
# Nearest to no: any, stepchildren, paxman, little, killaloe, discoweb, lkisch, regarder,
# Nearest to with: between, sniffin, loophole, fuehrer, suchet, in, hydroboration, sigilized,
# Nearest to is: was, has, are, became, becomes, be, contains, seems,
# Nearest to people: men, women, eildon, mohammedans, children, jews, philosophers, players,
# Nearest to used: known, defined, designed, available, found, written, held, classified,
# Nearest to to: will, perioikoi, dhanraj, cpt, nauk, kosteli, shortley, chipminck,
# Average loss at step 52000: 2.914785
# Average loss at step 54000: 2.879114
# Average loss at step 56000: 2.868238
# Average loss at step 58000: 2.755952
# Average loss at step 60000: 2.845952
# Nearest to for: without, zukuri, bivouacked, when, tzimtzum, variatione, against, hidaka,
# Nearest to only: either, drafted, buxom, helianthus, azati, mucor, histoclear, both,
# Nearest to but: however, although, and, though, while, see, until, mandruzzato,
# Nearest to state: states, capsid, communist, lorica, microdos, phamaceutical, ipfl, wiens,
# Nearest to of: although, including, in, during, folies, levick, bowmen, fehs,
# Nearest to in: during, within, at, under, throughout, stadtbahn, on, among,
# Nearest to up: off, out, him, back, down, sikosek, nutting, them,
# Nearest to been: become, be, matron, already, ginian, were, previously, grandchildren,
# Nearest to also: often, still, actually, usually, never, sometimes, which, typically,
# Nearest to one: two, four, six, five, eight, three, seven, apdl,
# Nearest to no: any, little, another, jutting, verwandter, nobody, regarder, khfar,
# Nearest to with: between, metacomet, suchet, loophole, millsaps, gyarmathi, tractate, divortium,
# Nearest to is: was, has, are, becomes, seems, means, does, remains,
# Nearest to people: men, women, children, eildon, jews, residents, citizens, authors,
# Nearest to used: designed, defined, known, available, classified, found, considered, referred,
# Nearest to to: perioikoi, will, should, would, could, dhanraj, might, colme,
# Average loss at step 62000: 2.854377
# Average loss at step 64000: 2.800529
# Average loss at step 66000: 2.769240
# Average loss at step 68000: 2.728071
# Average loss at step 70000: 2.841771
# Nearest to for: after, bivouacked, firebombed, hidaka, toti, intergovernmentalists, nowrap, condiment,
# Nearest to only: either, cruzan, finalists, subheading, azati, hymnody, punjabis, averments,
# Nearest to but: however, although, and, though, walsenburg, despite, lineally, he,
# Nearest to state: states, capsid, government, wiens, lorica, zanotto, charismata, coast,
# Nearest to of: including, in, veslefrikk, peiping, keyesville, during, bowmen, levick,
# Nearest to in: during, within, under, throughout, on, of, at, since,
# Nearest to up: off, out, down, back, sikosek, him, brookes, nutting,
# Nearest to been: become, be, grandchildren, matron, ginian, already, previously, walkthrough,
# Nearest to also: now, often, actually, never, still, usually, sometimes, mccaskill,
# Nearest to one: two, three, seven, otie, five, mahq, six, kiyooka,
# Nearest to no: any, regarder, jutting, another, libanaise, eclac, carrero, courageous,
# Nearest to with: between, loophole, suchet, when, droed, including, irons, bangladeshi,
# Nearest to is: was, has, are, remains, becomes, seems, includes, became,
# Nearest to people: women, men, children, eildon, jews, authors, citizens, countries,
# Nearest to used: defined, known, designed, referred, available, seen, accepted, allowed,
# Nearest to to: will, could, would, can, perioikoi, siskin, shortley, should,
# Average loss at step 72000: 2.798948
# Average loss at step 74000: 2.637500
# Average loss at step 76000: 2.806521
# Average loss at step 78000: 2.835105
# Average loss at step 80000: 2.790753
# Nearest to for: when, without, after, despite, substantia, bivouacked, nowrap, vidriera,
# Nearest to only: cruzan, either, divides, azati, primarily, buxom, relentlessly, easily,
# Nearest to but: however, although, though, and, see, until, specialties, mandruzzato,
# Nearest to state: states, piezo, capsid, lorica, wiens, philippine, city, cumberland,
# Nearest to of: keyesville, veslefrikk, in, folies, diceto, levick, westmore, peiping,
# Nearest to in: within, during, throughout, at, on, stadtbahn, near, krampf,
# Nearest to up: off, down, back, out, sikosek, nutting, brookes, them,
# Nearest to been: become, be, were, grandchildren, already, ginian, previously, walkthrough,
# Nearest to also: often, actually, sometimes, still, now, never, typically, commonly,
# Nearest to one: two, six, seven, three, eight, four, aphid, petropavlovsk,
# Nearest to no: any, little, peopling, jutting, nobody, regarder, courageous, libanaise,
# Nearest to with: between, suchet, pdnftt, droed, sigilized, milwaukeeans, loophole, millsaps,
# Nearest to is: was, has, becomes, are, remains, hypsipyle, contains, became,
# Nearest to people: women, men, children, authors, jews, citizens, individuals, fans,
# Nearest to used: known, designed, referred, defined, available, found, classified, useful,
# Nearest to to: must, perioikoi, will, would, should, can, cpt, kosteli,
# Average loss at step 82000: 2.667356
# Average loss at step 84000: 2.759199
# Average loss at step 86000: 2.731269
# Average loss at step 88000: 2.751870
# Average loss at step 90000: 2.731719
# Nearest to for: despite, of, after, itsuhaku, if, including, tabulator, zukuri,
# Nearest to only: either, until, drafted, primarily, cruzan, easily, readily, brazzilmag,
# Nearest to but: however, although, though, see, and, tox, mottled, or,
# Nearest to state: states, national, city, zanotto, remake, cumberland, sl, coast,
# Nearest to of: despite, for, keyesville, bowmen, including, suhuf, include, although,
# Nearest to in: within, during, on, throughout, near, stadtbahn, through, at,
# Nearest to up: down, off, back, out, sikosek, them, nutting, him,
# Nearest to been: become, be, were, grandchildren, ginian, watcher, already, matron,
# Nearest to also: now, often, never, actually, still, typically, sometimes, always,
# Nearest to one: two, four, six, seven, eight, lvares, gadgetinis, dryers,
# Nearest to no: any, little, another, courageous, peopling, jutting, readily, nobody,
# Nearest to with: between, loophole, bangladeshi, sigilized, stadtbahn, milwaukeeans, suchet, via,
# Nearest to is: was, has, are, becomes, remains, seems, includes, became,
# Nearest to people: women, children, jews, citizens, players, men, authors, individuals,
# Nearest to used: designed, defined, known, found, presented, classified, useful, described,
# Nearest to to: would, must, should, perioikoi, dhanraj, shortley, cannot, can,
# Average loss at step 92000: 2.666585
# Average loss at step 94000: 2.727760
# Average loss at step 96000: 2.696160
# Average loss at step 98000: 2.373760
# Average loss at step 100000: 2.409978
# Nearest to for: after, bivouacked, nowrap, without, despite, geomagnetic, laxmanniaceae, including,
# Nearest to only: either, doubled, until, cruzan, ekr, last, enriching, riktning,
# Nearest to but: however, although, though, and, while, despite, until, oversaw,
# Nearest to state: states, capsid, zanotto, city, taizhou, concurso, citadelle, assumption,
# Nearest to of: in, despite, levick, although, veslefrikk, suhuf, fehs, hofert,
# Nearest to in: during, within, at, throughout, near, of, on, inderal,
# Nearest to up: off, down, back, out, sikosek, nutting, together, them,
# Nearest to been: become, be, already, ginian, previously, were, grandchildren, specially,
# Nearest to also: actually, still, now, often, never, which, typically, sometimes,
# Nearest to one: tayste, babalugats, two, voroshilovgrad, sauve, knowledgebase, zorkmid, sugarbaker,
# Nearest to no: any, little, nobody, qemm, surrouned, jutting, magicnet, uu,
# Nearest to with: between, cumming, suchet, during, sigilized, merisant, sausages, within,
# Nearest to is: was, has, remains, are, seems, becomes, became, chloroammonia,
# Nearest to people: women, children, men, citizens, players, jews, individuals, authors,
# Nearest to used: designed, defined, known, referred, presented, described, called, adopted,
# Nearest to to: would, will, should, must, can, might, could, fatmir,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
